# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
MASTER_PATH = "/content/drive/MyDrive/BOUN COURSES/SWE 522/02-PROJECTS/Project-2/FR-Refactor"

# %% [markdown]
# CREATE DATASET

# %%
import pandas as pd
import pickle

if __name__ == '__main__':

    f = open(MASTER_PATH + '/src/dataset/final_dataset.pickle', 'rb')
    dataset = pickle.load(f)
    f.close()
    print("dataset laoded.....")
    print('==========>')


    binary_class_dataset = []
    for index in range(len(dataset)):
        task = []
        task.append(dataset[index][0])
        if isinstance(dataset[index][1], int):
          ref = dataset[index][1]
        else:
          if str(dataset[index][1][0]).strip() == 'none':
            ref = 0
          else:
            ref = dataset[index][1]
        task.append(ref)

        binary_class_dataset.append(task)

    f = open(MASTER_PATH + '/src/dataset/final_dataset.pickle', 'wb')
    pickle.dump(binary_class_dataset,f)
    f.close()
    print("dataset saved.....")
    print('==========>')

    print(binary_class_dataset[0])
# Out:
# dataset laoded.....
# ==========>
# dataset saved.....
# ==========>
# [' anoth blueprint sampl contribut day test blueprint mbean gener complex blueprint sampl sampl user learn defin nest compon blueprint xml run sampl besid osgi framework bundl requir coreopt mavenbundl groupid org apach felix artifactid org apach felix configadmin versionasinproject coreopt mavenbundl groupid org apach felix artifactid org apach felix eventadmin versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log api versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log servic versionasinproject coreopt mavenbundl groupid org apach ari blueprint artifactid org apach ari blueprint versionasinproject coreopt mavenbundl groupid org apach ari artifactid org apach ari util coreopt mavenbundl groupid org apach ari jmx artifactid ari jmx blueprint versionasinproject', 0]

# %%
dataset
# Out:
# [[' anoth blueprint sampl contribut day test blueprint mbean gener complex blueprint sampl sampl user learn defin nest compon blueprint xml run sampl besid osgi framework bundl requir coreopt mavenbundl groupid org apach felix artifactid org apach felix configadmin versionasinproject coreopt mavenbundl groupid org apach felix artifactid org apach felix eventadmin versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log api versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log servic versionasinproject coreopt mavenbundl groupid org apach ari blueprint artifactid org apach ari blueprint versionasinproject coreopt mavenbundl groupid org apach ari artifactid org apach ari util coreopt mavenbundl groupid org apach ari jmx artifactid ari jmx blueprint versionasinproject',
#   0],
#  [' blueprintcontainerimpl add info log blueprint contain creat look issu reload ari blueprint need turn debug log variou packag see goe miss also normal usag info log log blueprint contain creat eg blueprintcontainerimpl code code eventdispatch blueprintev new blueprintev blueprintev creat getbundlecontext getbundl getextenderbundl state state creat code suggest add info log detail blueprint contain creat peopl easier spot contain creat log need enabl debug log look blueprinteventdispatch send even creat',
#   0],
#  [' creat basic build structur ari jpa compon creat basic structur jpa compon ari',
#   0],
#  [' ad back home link teh blog sampl', 0],
#  [' documant blog sampl run code organis add web page document', 0],
#  [' excess io instal subsystem initi root subsystem notic activ subsystem core bundl take long time start subsystem core lot io done establish constitu root subsystem particular environ 120 bundl bundl end constitu root subsystem call org apach ari subsystem core intern subsystem getrootsubsystem deploy manifest root subsystem rewritten constitu detect file content get progress larger constitu ad end 121 time whole file get written final content file end around 14 kb two observ bufferedoutputstream use write deploy manifest sinc file grow sever kb size would optim use buffer output stream avoid write persist deploy manifest success instal done end write complet deploy manifest',
#   0],
#  [' abl easili use blueprint insid war servlet contain use blueprint noosgi servletcontextlisten boot blueprint xml file initi patch submit pull request first cut basic let war servlet engin act like blueprint osgi sens jar includ blueprint xml file meta inf blueprint xml differenti osgi base configur servletcontextlisten use find blueprint xml file classpath depend jar war boot everyth',
#   0],
#  [' integr version plugin subsystem modul releas', 0],
#  [' updat ari jpa implement osgi support hibern fork ari jpa updat jpa need test bed spec yet current final draft hope soon vote fork use hibern current implement api creat pull request work case want start point whenev begin support pretti simplist updat pom manifest ad un implement method etc sever place featur new may need implement howev may need throw unsupport pull request http github com apach ari pull feel free take leav',
#   0],
#  [' revisit use coordin order take advantag deploy manifest optim ari 1034 introduc optim save deploy manifest delay coordin present subsystem oper affect deploy manifest revist make use coordin order take advantag chang',
#   0],
#  [' org apach ari subsystem core intern activ need improv current org apach ari subsystem core intern activ class org apach ari subsystem core intern subsystemresolverhookfactori class curiou code follow activ new subsystem throw subsystemexcept addingservic method suggest follow write overrid public synchron object addingservic servicerefer object refer object servic bundlecontext getservic refer servic instanceof idirectoryfind finder add idirectoryfind servic return servic els servic instanceof repositori repositori add repositori servic return servic els servic instanceof coordin coordin null coordin coordin servic els servic instanceof regiondigraph regiondigraph null regiondigraph regiondigraph servic els servic instanceof resolv resolv null resolv resolv servic els servic instanceof modelledresourcemanag modelledresourcemanag null modelledresourcemanag modelledresourcemanag servic activ return servic subsystemresolverhookfactori class constructor never seen follow explicitli throw npe subsystem null throw new nullpointerexcept miss requir paramet subsystem suggest better use runtimeexcept illegalargumentexcept',
#   0],
#  [' publish singl interfac better integr transactionmanag low level compon integr geronimo connector librari quit hard use ari transact manag interfac expos expos singl interfac inherit need one eas work lot',
#   0],
#  [' releas latest org apach ari jndi core http svn apach org repo asf ari trunk jndi jndi core src main java org apach ari jndi objectfactoryhelp java need follow code mehtod getobjectinstanceviacontextdotobjectfactori class factori instanceof dirobjectfactori logger log level fine dirobjectfactori final dirobjectfactori dirfactori dirobjectfactori factori result dirfactori getobjectinst obj name namectx environ attr http src springframework org svn spring ldap trunk core src main java org springframework ldap core support defaultdirobjectfactori java public object getobjectinst object obj name name context namectx hashtabl environ throw except return null',
#   0],
#  [' add way use properti placehold defin filter servic refer idea defin ext filter attribut would valuemetadata properti substitut would take place placehold',
#   0],
#  [' creat either synchronis entiti manag proxi creat entiti manag request use apach ari contain manag transact jta hibern persist start multipl thread read databas without transact transact annot ommit get follow stacktrac org hibern assertionfailur possibl non threadsaf access session org hibern engin intern twophaseload initializeent twophaseload java 130 org hibern loader loader initializeentitiesandcollect loader java 1103 org hibern loader loader processresultset loader java 960 org hibern loader loader doqueri loader java 910 org hibern loader loader doqueryandinitializenonlazycollect loader java 341 org hibern loader loader dolist loader java 2516 org hibern loader loader dolist loader java 2502 org hibern loader loader listignorequerycach loader java 2332 org hibern loader loader list loader java 2327 org hibern loader hql queryload list queryload java 490 org hibern hql intern ast querytranslatorimpl list querytranslatorimpl java 355 org hibern engin queri spi hqlqueryplan performlist hqlqueryplan java 195 org hibern intern sessionimpl list sessionimpl java 1247 org hibern intern queryimpl list queryimpl java 101 reason got except non transact mode inject entitymanag implement use differ request multipl thread unfortun entitymanag thread safe refactor code inject entitymanagerfactori instead sinc entitymanagerfactori thread safe creat entitymanag method programmat ari stand point abl improv order eas pain creat synchron entiti manag proxi creat entiti manag request proxi would probabl follow creat entitymanag perform request close entitymanag',
#   0],
#  [' inject support fluent setter method pleas look support fluent setter current ari reflectionutil allow method return type void seem restrict also spring support see section http static springsourc org spring doc releas spring framework refer html new html',
#   0],
#  [' provid common schema xml namespac schema use xml namespac thing xml lang xml base etc need import http www w3 org xml 1998 namespac blueprint could provid namespac handler namespac avoid bunch differ bundl add namespac handler',
#   0],
#  [' introduc blueprintextenderservic simplifi manag blueprintcontain code easi creat blueprintcontain code blueprintextend main piec code deal contain propos introduc blueprintextenderservic make straght forward interest consum creat use blueprintcontain patch commun review follow anoth jira support specif use case open shortli',
#   0],
#  [' introduc blueprint web osgi modul exist blueprint web modul depend non osgi blueprint modul case necessari abl access creat blueprintcontain given bundl way blueprint web osgi environ exampl custom servlet depend osgi awar blueprint servletcontextlisten listen use propos blueprintextenderservic creat blueprintcontain set servletcontext attribut custom servlet check blueprintcontain extract requir applic compon',
#   0],
#  [' updat blueprint core ari modul blueprint core releas consist upgrad ari modul use blueprint core version',
#   0],
#  [' support blueprintnullproxi blueprint rfc http github com osgi design tree master rfc rfc0184 add concept null proxi support reason easili requir updat ari proxi api',
#   0],
#  [' use header resolv depend bundlestatembean bundlestatembean getimportedpackag long bundleid getrequiredbundl long method resolv depend use iter bundl framework perform method improv first check manifest header use valu packageadmin queri note bundl use dynamicimport still requir full iter',
#   0],
#  [' abil disabl blueprint schema valid via system properti ari blueprint code allow schema valid disabl ad bundl symbol name direct _blueprint ari xml valid false_ unfortun must done bundl contain blueprint descriptor inclus ari blueprint jar also contain blueprint descriptor would nice disabl schema valid global bundl deploy osgi contain perform impact valid xsd embed devic valid xsd quiet expens necessari product code blueprint code alreadi check direct blueprintcontainerimpl code string xmlvalidationdirect headerpars pathel path get getdirect blueprint ari xml valid xmlvalidationdirect null logger debug xml valid direct xmlvalidationdirect xmlvalid boolean parseboolean xmlvalidationdirect code cheer micha',
#   0],
#  [' allow refer refer filter servic multipl interfac relat ari 1140 servic regist multipl class interfac howev refer use singl interfac lookup case would good provid via ext namespac way refer implement addit interfac also restrict refer servic implement extra interfac',
#   0],
#  [' ari subsystem use org osgi servic repositori repositori interfac problemat ari subsystem work osgi repositori provis resourc requir osgi subsystem spec howev implement also implement repositori interfac provid repositori facad thing like felix repositori esa content thing look relev import packag header see defin follow org osgi servic repositori version problemat sinc repositori interfac provid type henc version contain new method use repositori break current subsystem implement local repositori facad implement repositori interfac chang version rang good idea either limit integr repositori servic make subsystem work repositori implement want keep import org osgi servic repositori version tact need chang subsystem implement way continu work repositori interfac move new method ad',
#   0],
#  [' add support creat non xa datasourc actual need xadatasourc get handl transact jdbc might use one abstract layer configur either non xa datasourc xadatasourc way capabl pool error handl may gener way provid specif driver class inform benefit uniqu approach would get kind datasourc configur way top geronimo core librari transact flag none local xa might use distinct',
#   0],
#  [' esa maven bundl without packag type esa case pom packag type cannot esa bundl add pom artefact subsystem scenario pom packag type bundl maven bundl plugin bundl suppos packag subsystem depend',
#   0],
#  [' jmx whiteboard also accept interfac end mxbean mbean jmx whiteboard requir mbean servic implement interfac name class mbean port system use ari whole lot mxbean instead regular mbean get ignor mistaken function mxbean subset mbean think would make sens ari accept mxbean tri local trunk seem trick guy gal interest trivial patch',
#   0],
#  [' make subsystem independ applic model modelledresourcemanag option packag depend',
#   0],
#  [' upgrad asm order support java8 ari proxi ari spifli uprad asm5', 0],
#  [' upgrad proxi impl asm java support ari proxi work java sinc depend asm support java current blocker work karaf java karaf contain ari proxi impl upgrad asm requir chang super call ari subclass asm class tri local build ari proxi impl snapshot chang result seem ok karaf larger part issu ari side depend prehistor version pax exam depend pax runner addit configur tweak ari support java either abl run proxi integr test',
#   0],
#  [' remov pax exam depend org apach ari testsupport unit like describ http mail archiv apach org mod_mbox ari dev 201405 mbox 3c5370e1ea 9040008 40die schneider net 3e propos remov pax exam depend org apach ari testsupport unit reason think make sens testsupport use mani ari project mani need pax exam depden depend bind project particular pax exam version increas coupl pax exam need two class test support extraopt abstractintegrationtest extraopt realli necessari newer pax exam version featur avail directli pax exam dsl abstractintegrationtest use pax exam inject pax exam replac javax inject depend necessari anymor far know mean need new major version testsupport remov public class provid patch',
#   0],
#  [' updat transact integr test pax exam', 0],
#  [' updat ari proxi integr test pax exam', 0],
#  [' updat jndi integr test pax exam', 0],
#  [' web urlhandl depend blueprint blueprint context org apach ari web urlhandl project regist two simpl servic done way use plain java bundleactiv get rid unnecessari blueprint depend',
#   0],
#  [' maven plugin creat ari applic archiv would nice plugin maven creat ari applic archiv someth similar maven ear plugin maven war plugin ari applic',
#   0],
#  [' forward javax persist jdbc properti datasourcefactori alreadi possibl refer datasourc persist xml defin javax persist jdbc driver instead jndi datasourc implement look datasourcefactori servic problem foward three properti factori url user password usabl derbi datasourcefactori provid ops4j datasourc requir databasenam work url user password would like chang code datasourcefactorydatasourc accept complet properti object object fill persist unit copi properti start javax persist jdbc remov prefix allow configur datasourcefactori requir hope misus javax persist jdbc properti namespac good idea pleas speak',
#   0],
#  [' convert applicationmetadatamanag simpl factori improv applic javadoc tidi loos end ari 89 applicationmetadatamanag need facotri api javadoc could improv',
#   0],
#  [' add connect valid featur jdbc ari transact jdbc lack support connect valid datasourc pool',
#   0],
#  [' switch ejb model itest pax exam', 0],
#  [' use system bundl track namespac handler bundl blueprint implement current use bundlecontext track namespac handler caus issu namespac handler contain subsystem one approach support namespac handler contain applic subsystem would blueprint use system bundl context track namespac handler blueprint also use org apach ari util tracker recursivebundletrack track bundl blueprint compon recursivebundletrack understand composit know recurs track blueprint contain composit bundl make depend recursivebundletrack option fallback use system bundl context track blueprint would allow support subsystem blueprint',
#   0],
#  [' fix requir provid servic proxymanag', 0],
#  [' npe thrown getbundlecontextact hi current investig npe thrown getbundlecontextact stack trace java lang nullpointerexcept org apach ari subsystem core intern getbundlecontextact run getbundlecontextact java 35 org apach ari subsystem core intern getbundlecontextact run getbundlecontextact java 22 java secur accesscontrol doprivileg accesscontrol java 273 org apach ari subsystem core intern basicsubsystem getbundlecontext basicsubsystem java 186 snip know caus look getbundlecontextact line 35 contain nest method invoc one return null like submit suggest follow patch split line add basic error check index getbundlecontextact java getbundlecontextact java revis 1607078 getbundlecontextact java work copi 16 16 import java secur privilegedact import java util enumset import org eclips equinox region region import org osgi framework bundl import org osgi framework bundlecontext import org osgi servic subsystem subsystem state 26 15 28 23 subsystem subsystem overrid public bundlecontext run enumset state install_fail state uninstal contain subsystem getstat return null basicsubsystem subsystem util findscopedsubsysteminregion subsystem return subsystem getregion getbundl regioncontextbundlehelp symbolicname_prefix subsystem getsubsystemid regioncontextbundlehelp version getbundlecontext region region subsystem getregion region null return null cover call regiondigraph getregion name return null bundl bundl region getbundl regioncontextbundlehelp symbolicname_prefix subsystem getsubsystemid regioncontextbundlehelp version bundl null null bundl return null return bundl getbundlecontext',
#   0],
#  [' allow perserservic pars success namespac handler miss blueprint parserservic expos blueprint parser bundl great allow bundl model reason blueprint depend parserservic current fail componentdefinitionexcept custom namespacehandl use within compon xml file pars custom namespacehandl servic current regist becom pain scenario tri reason depend group bundl one bundl provid namespacehandl servic use runtim bundl group exampl osgi subsystem may instal group bundl content subsystem implement ari attempt model blueprint depend bundl resourc actual instal start bundl done use blueprint parserservic alway fail blueprint xml use custom namespac fail model correctli ultim result subsystem instal failur would nice parserservic could configur ignor miss namespacehandl continu model basic blueprint xml one way accomplish would framework properti configur ignor namespac miss use parserservic chang behavior parserservic intern usag parser implement blueprint core also chang current behavior parserservic unless option ignor enabl explicitli anoth option chang parserservic api somehow pass option ignor unknown namespacehandl unfortun side effect explod api parserservic mani layer built top parserproxi modelledresourcemanag get use ari subsystesm perhap correct thing comfort chang much api usecas global switch simpli enabl option ignor miss namespacehandl good enough usag other want add api allow client api make choic fine would prefer done someon familiar overal api',
#   0],
#  [' allow extern access felix osgi adapt org apach ari subsystem obr intern hi current write code access felix repositori allow interact repositori via osgi interfac someth ari insid org apach ari subsystem obr intern packag number class provid abil adapt osgi felix felix osgi class question felixcapabilityadapt java felixproperti java felixrepositoryadapt java felixrequirementadapt java felixresourceadapt java osgicapabilityadapt java osgicontentcap java osgiidentitycap java osgirequirementadapt java osgiresourceadapt java rather invent wheel take copi would like propos class move packag subsequ export extern use scan import statement none look refer ari intern class believ simpl refactor would requir',
#   0],
#  [' entitymanagerfactorymanag remov tri creation entitymanagerfactori bundl resolv event entitymanagerfactorymanag alreadi mention ari 1160 see benefit tri creat entitymanagerfactori bundl resolv event time bundl resolv bundl context still initi tri creation entitymanagerfactori like fail hibern eclipselink implement fail lookup datasourc servic confus user stack trace entitymanagerfactori creat tick later bundl activ event call registerentitymanagerfactori method patch attach',
#   0],
#  [' remov blueprint depend ari transact jm make xbean depend option depend blueprint provid activ like ari transact jdbc',
#   0],
#  [' use gener capabl requir servic', 0],
#  [' add blueprint maven plugin recent creat maven plugin gener blueprint xml cdi jee spring annot http github com cschneider blueprint maven plugin make differ blueprint annot support alreadi got ari blueprint annot follow xml style bind exact bean id annot use default bind simpli type much simpler manag line spring autowir cdi inject still also allow bind name use name ari blueprint annot process runtim creat xml cover plugin hand work build time runtim instal exist contain run blueprint addit dep need plugin use standard cdi jee annot standard servic pax cdi annoat peopl use style transit real cdi quit easili peopl jee background also feel home style plugin also support spring annot like autowir compon valu allow fast migrat spring blueprint fact use quit big custom project case sampl applic creat exampl applic show follow featur intern wire contain manag jpa transact use offer osgi servic http github com cschneider karaf tutori tree master tasklist cdi',
#   0],
#  [' improv log output destroy blueprintcontain blueprintextend destroycontain method logger info destroy blueprintcontain bundl bundl getsymbolicnam besid symbol name also display version inform perhap best consid log output use bundl getsymbolicnam includ version',
#   0],
#  [' refactor blueprint nshandler class nshandler quit larg especi decor method long difficult understand fast plan extract emfservic ref creation separ class extract part method',
#   0],
#  [' support type configur properti placehold possibl configurationadmin put complex type configur object list array return configur ari placehold get crazi tri convert retriev valu string back type requir bean',
#   0],
#  [' name unnam maven project sourc tree build ari sourc stumbl upon follow info unnam org apach ari jpa jpa contain testbundl bundl incub snapshot success 317 info unnam org apach ari jpa jpa contain itest jar incub snapshot success 12 326 miss proper name possibl fals assumpt default name maven project proper',
#   0],
#  [' noosgi blueprintcontextimpl accept custom namespac handler set', 0],
#  [' ant esa taskdef ari user would like ant base task would gener enterpris servic archiv esa',
#   0],
#  [' support produc annot blueprint maven plugin blueprint creat bean use factori ref factori method jee done use produc anntat factori support produc annot blueprint maven plugin translat gener two bean code result xml singleton public class myfactorybean produc public myproduc creat return new myproduc messag public class myproduc privat string messag public myproduc string messag messag messag public string getmessag return messag bean id myfactorybean class org apach ari blueprint plugin test myfactorybean ext field inject true bean bean id myproduc class org apach ari blueprint plugin test myproduc ext field inject true factori ref myfactorybean factori method creat bean',
#   0],
#  [' support special blueprint bean like blueprintbundlecontext blueprint defin special bean id return defin instanc blueprintbundlecontext bundlecontext blueprintbundl bundl blueprintcontain blueprintcontain blueprintconvert convert class support maven blueprint plugin',
#   0],
#  [' subsystem command ari subsystem user would prefer ari subsystem implement provid subsystem instal command would help user standard bundl oper instal start stop updat uninstal esa archiv',
#   0],
#  [' support env xxx variabl substit environ variabl', 0],
#  [' upgrad blueprint test pax exam', 0],
#  [' upgrad geronimo transact manag', 0],
#  [' upgrad applic pax exam', 0],
#  [' sampl implement promis api osgi r6 asynchron servic osgi asynchron servic rfc 206 defin new promis api releas r6 framework 100kb patch sampl implement promis api creat scratch use api defin rfc 206 aim quickli creat conform implement best implement code undoubtedli improv contain unit test may miss test case formal compat test derek baum paremu com',
#   0],
#  [' basic implement async servic osgi asynchron servic rfc 206 provid use tool make asynchron invoc osgi servic ari implement servic abl contribut basic function complet version',
#   0],
#  [' reduc memori alloc org apach ari blueprint proxi collabor class case intens usag memori cpu overhead org apach ari blueprint proxi collabor easi elimin stack thread safeti overhead replac arraydequ stack use singl thread case interceptor make sens alloc time stack object refer set null static immut empti stack valu',
#   0],
#  [' introduc namespac annot appli blueprint parser compon namespacehandl interfac list namespac handler support make difficult autom registr handler non osgi context namespac annot provid option mechan namespacehandl advertis list support namespac help discov handler non osgi context also introspect osgi need',
#   0],
#  [' updat blueprint web servletcontextlisten option regist namespacehandl option use blueprintnamespacehandl context paramet code xml web app context param param name blueprintloc param name param valu web inf bean xml param valu context param context param param name blueprintnamespacehandl param name param valu param valu context param listen listen class org apach ari blueprint web blueprintcontextlisten listen class listen rest web app web app code option check meta inf blueprint handler class resourc handler resourc list one namespacehandl class exampl noformat noformat web xml look much simpler code xml web app context param param name blueprintloc param name param valu web inf bean xml param valu context param listen listen class org apach ari blueprint web blueprintcontextlisten listen class listen rest web app web app code',
#   0],
#  [' allow use blueprint annot configur file simultan current possibl mix blueprint annot configur file bundl case use tx enabl annot autzh enabl necessari use configur file side annot closer code would great allow use blueprint annot configur file simultan',
#   0],
#  [' allow defin bean id servic ref want refer two servic classnam interfac differ packag current get bean id deriv sole classnam interfac need way defin bean id case suitabl way enabl name qualifi osgiservic ref',
#   0],
#  [' improv inform provid servic unavail tri use applic see error similar follow 31 01 10 17 58 14 166 gmt 00000011 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop persist java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000012 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop warehous java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000013 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop admin java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000011 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop search java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 current order diagnos gone wrong necessari turn trace inform provid necessari turn trace',
#   0],
#  [' remov codehaus repo add ops4j snapshot repo', 0],
#  [' upgrad maven releas plugin', 0],
#  [' updat parent', 0],
#  [' noosgi simplenamespacehandlerset tri resolv rel schema refer', 0],
#  [' avoid use ari util eclipselink adapt', 0],
#  [' upgrad geronimo transact manag', 0],
#  [' entitymanag reus seri coordin call consid scenario blueprint servic jpa code find return em find void delet em remov code blueprint bean inject call method within transact code transact b1 find entiti return find em find delet entiti attach code reason method bean proxi follow way code emsuppli precal emsuppli get find delet emsuppli postcal code method call get em find one em delet anoth one entiti manag within first em second em share transact within singl thread singl method call pleas also note transact could jta use differ unit singl transact scenario bundl a1 a2 a3 persist jpa expos entiti servic domain modul bundl a1 a2 a3 use differ schema databas differ unit name bundl b1 b2 b3 rest servic use entiti servic transact separ domain logic busi logic b1 b2 b3 use method a1 a2 a3',
#   0],
#  [' work exampl transact annot attach work exampl code transact annot place improv inlin bean scan beanmetadata null case one without id servic bean servic',
#   0],
#  [' basicsubsystem use subsystem instal process factor time faster problem poor perform instal subsystem contain 200 subsystem instal perform analys subsystem instal process notic basicsubsystem work lot manifest instead pre calcul data use lot use pre patch version basicsubsystem subsystem instal 200 run subsystem could take minut use patch version pre calcul highli use data new subsystem manifest deploy manifest set could bring 10 second pre calcul data highli use',
#   0],
#  [' perform improv findprovid method systemrepositori class two improv patch applic subsystem process method applic subsystem share capabl think work like mayb wrongli interpret specif process constitu store set process encount differ subsystem share across featur use 60 featur share bundl use process 60 time',
#   0],
#  [' support coordin trigger transact marker new jpa compon use coordin manag lifecycl jpa entitymanag blueprint transact support creat coordin transact marker allow jpa entitymanag control lifecycl larger dao method exampl servic method call sever dao method mark transact creat coordin method close entitymanag whole servic method servic method need transact annot txtype support case coordin start em lifecycl declar use annot without perform impact transact',
#   0],
#  [' add switch gener annot base style jpa', 0],
#  [' remov remain nl usag except log messag use nl support remov rest unifi handl',
#   0],
#  [' allow jta annot configur transact ari transact blueprint differ way configur transact xml bean level use wildcard xml bundl level use wildcard ari transact annoat jta standard transact annot code need work option new major version plan allow jta style make code well document consider smaller',
#   0],
#  [' provid option disabl provis depend instal time problem subsystem specif state depend subsystem must instal order attain instal state requir depend found instal must fail function describ order achiev fail fast function environ cannot support depend subsystem reject right away howev deploy situat valuabl delay instal depend exampl may wish independ simultan instal suit subsystem whose content interleav depend current possibl local repositori one subsystem avail other resourc avail other becom part system repositori assum compat share polici instal state acquir meantim subsystem fail instal three potenti workaround issu none may accept particular subsystem consum provid content part remot repositori note would requir subsystem content header comput subsystem provid implement packag subsystem singl esa make use parent child relationship manag instal order manual note would handl case circular depend solut allow independ simultan instal multipl subsystem interleav content depend thu give deploy flexibl desir propos solut custom direct introduc apach ari provis depend possibl valu instal resolv indic time depend provis occur default valu instal result current behavior direct may specifi part subsystem type header valu resolv indic depend provis instal time rather step occur subsystem resolv typic happen part start process subsystem apach ari provis depend resolv remain instal state start indic administr program monitor subsystem via servic registri subsystem yet depend provis subsystem start transit instal instal occur today assum provis depend succe subsystem immedi transit resolv state proceed normal state transit apach ari provis depend start instal void instal void instal install_fail uninstal uninstal instal fail reason depend provis start instal instal resolv resolv start activ instal instal provis depend fail instal instal resolv instal runtim resolut fail instal instal resolv resolv start resolv start fail child scope subsystem inherit apach ari provis depend valu first scope ancestor unless explicitli overridden unscop subsystem alway inherit apach ari provis depend valu first scope ancestor may overrid valu root subsystem alway valu apach ari provis depend instal altern solut make local repositori instal subsystem avail instal subsystem specif allow local repositori regist repositori servic although explicitli address possibl particular implement share intern nevertheless intent spec seem clear assum subsystem provid desir content share other potenti issu propos solut break contract instal method specifi subsystem ariessubsystem interfac requir either return subsystem instal state instal fail except howev assum explicit declar apach ari provis depend direct valu resolv grant implement permiss altern would return subsystem instal state even though none depend instal howev would also violat specif may confus third parti applic monitor subsystem servic via registri subsystem may one parent one scope parent mean addit parent alway featur unscop subsystem question apach ari provis depend inherit work multipl parent conflict valu simplifi assumpt would featur may overrid valu scope parent impli featur fail instal contain valu apach ari provis depend conflict scope subsystem within region test case set subsystem interleav content depend abl independ simultan success instal start subsystem apach ari provis depend resolv instal state success instal subsystem apach ari provis depend resolv avail servic success instal subsystem apach ari provis depend resolv depend instal success instal subsystem apach ari provis depend resolv undergo follow state transit start instal instal resolv resolv start activ subsystem apach eari provis depend resolv depend instal success start subsystem apach ari provis depend resolv install_fail state unsuccess instal subsystem apach ari provis depend resolv avail servic unsuccess instal subsystem apach ari provis depend resolv instal state depend cannot provis invok start method 10 subsystem fail inst ...
#   0],
#  [' comput requir filter resourcehelp match requir capabl often use method resolut current recomput requir filter call measur use test scenario develop part ari 1357 time took instal 50 featur measur featur consist 10 bundl plu one applic featur share 10 bundl bundl export uniqu packag applic consist 10 uniqu bundl bundl import packag offer contain featur baselin averag time instal 50 featur 67 second abstractrequir lazili comput requir filter ask first time subsequ call return alreadi comput valu resourcehelp ask whether requir instanc abstractrequir ask filter directli filter comput modif averag time instal 50 featur 46 second 31 improv',
#   0],
#  [' basiccap take advantag effect immut capabl current given alreadi exist capabl construct basiccap make copi attribut direct realli necessari sinc properli implement capabl effect immut requir osgi api profil show basiccap capabl resourc take 1550 ms total time optim longer regist sampl time 50 ms basiccap capabl resourc simpli reus alreadi exist effect immut attribut direct map provid capabl',
#   0],
#  [' provid effici implement local content repositori measur use new test scenario help flush bottleneck local content repositori time took instal applic measur applic consist 200 bundl half bundl export 50 packag half bundl import 50 packag give total 5000 requir 5000 capabl averag time across trial 13915 ms averag time across trial 14628 ms averag time across trial 14196 ms averag time across trial 13905 ms averag time across trial 14021 ms 14133 averag time across trial 7781 ms averag time across trial 7782 ms averag time across trial 8085 ms averag time across trial 7850 ms averag time across trial 7971 ms 7893 44 overal improv obtain subsystem region took 2254 ms 14 cach region context bundl use perform region lookup effort longer regist profil 50 ms sampl period find provid local repositori took 2260 ms 15 ad capabl set took 747 ms ask whether resourc content took 2152 ms 16 answer use exist content resourc set rather content header effort longer regist profil 50 ms sampl period find provid content repositori took 4510 ms 28 ad capabl set took 49 ms',
#   0],
#  [' add structur option blueprint xml valid featur current xml valid perform blueprint bean file default one disabl valid set blueprint ari xml valid fals avail option either full valid valid use case practic disabl datatyp valid keep structur valid request add option pass appropri errorhandl valid instanc datatyp specif valid error ignor',
#   0],
#  [' use capabl set calcul subsystem depend measur use beef version test ari 1394 time took instal applic measur applic consist 300 bundl 200 bundl export 50 packag 100 bundl import 50 packag give total 5000 requir 10 000 capabl 100 export bundl serv prefer provid calcul depend took 6728 ms 43 make use capabl set took 2005 ms 18 baselin averag time across trial 13841 ms averag time across trial 13820 ms averag time across trial 13982 ms averag time across trial 13599 ms averag time across trial 13782 ms 13804 dependencycalcul use capabl set averag time across trial 9923 ms averag time across trial 10247 ms averag time across trial 10180 ms averag time across trial 10212 ms averag time across trial 10442 ms 10200 26 overal improv',
#   0],
#  [' use capabl set prefer provid repositori measur use test ari 1396 time took instal applic measur applic consist 300 bundl 200 bundl export 50 packag 100 bundl import 50 packag give total 5000 requir 10 000 capabl 100 export bundl serv prefer provid find provid prefer provid repositori took 3305 ms 25 make use capabl set took 948 ms baselin averag time across trial 12974 ms averag time across trial 12597 ms averag time across trial 12760 ms averag time across trial 12573 ms averag time across trial 12339 ms 12648 prefer provid repositori use capabl set averag time across trial 10917 ms averag time across trial 10562 ms averag time across trial 10743 ms averag time across trial 10718 ms averag time across trial 10471 ms 10682 15 improv',
#   0],
#  [' make sure bundl goe graceperiod servic need jpa present current coordin well entitymanag servic inject use manual creat servic proxi problem stop blueprint start user context way jpa enabl bean start even prerequisit yet present lead call block runtim servic timeout error report also bad know someth went wrong first call timeout idea use correct blueprint metadata servic ref make blueprint go graceperiod servic present diag command also show miss current approach beanprocessor support approach se need switch componentdefinitionregistryprocessor recommend guillaum nodet',
#   0],
#  [' add karaf itest test exampl', 0],
#  [' switch namespac namespac enabl element like jpa instal togeth old transact bundl support smooth transit',
#   0],
#  [' allow configur code gener base namespac idea configur gener code specifi namespac use configur look like namespac namespac http ari apach org xmln jpa v2 namespac namespac http ari apach org xmln transact v2 namespac namespac namespac configur two assum list initi support namespac config http ari apach org xmln jpa v1 http ari apach org xmln jpa v2 http ari apach org xmln transact v1 http ari apach org xmln transact v2 namespac caus gener xml element namespac gener respect enabl element',
#   0],
#  [' ari subsystem implement bundl must provid offici capabl compendium v6 state 134 19 capabl capabl osgi implement namespac declar implement specif osgi subsystem capabl must also declar use constraint org osgi servic subsystem packag exampl code provid capabl osgi implement osgi implement osgi subsystem version version use org osgi servic subsystem code capabl must follow rule defin osgi implement namespac page 997 capabl osgi servic namespac repres subsystem servic capabl must also declar use constraint org osgi servic subsystem packag exampl code provid capabl osgi servic objectclass list string org osgi servic subsystem subsystem use org osgi servic subsystem code',
#   0],
#  [' add declar transact support apach ari aim alllow declar transact use via blueprint la jee declar transact support exampl blueprint xmln http www osgi org xmln blueprint v1 xmln xsi http www w3 org 2001 xmlschema instanc xsi schemaloc http www osgi org xmln blueprint v1 xmln tx http ari apach org xmln transact v1 default activ lazi bean id persistenceimpl class org apach ari sampl blog persist blogpersistenceserviceimpl tx transact method valu requir bean blueprint',
#   0],
#  [' support m2e increment build blueprint maven plugin', 0],
#  [' cm manag compon destroy method call singl integ argument destroy method cm manag compon consid compat method contain singl integ argument requir use placehold integ argument requir lead confus use blueprint cm code titl cmmanagedservicefactori java borderstyl solid privat method finddestroymethod class clazz method method null componentdestroymethod null componentdestroymethod length list method method reflectionutil findcompatiblemethod clazz componentdestroymethod new class int class method null method isempti method method get return method code',
#   0],
#  [' wsdl2java also gener dual channel client code current wsdl2java gener client stub sync osync call singl connect commun sinc axis2 support also dual channel commun tool also gener java code blockingdualcli stub nonblockingdualcli stub',
#   0],
#  [' wsdl return ip address instead hostnam may relat axis2 700 fix ip address return instead hostnam url wsdl file deo make url less robust machin dyanmic ip address',
#   0],
#  [' replac servic endpoint serv origin wsdl use useoriginalwsdl param use recent ad useoriginalwsdl attribut servic xml serv wsdl meta inf thank fix would nice replac endpoint address use request url context serv origin wsdl',
#   0],
#  [' improp error messag display click upload button without select archiv follow error messag display user click upload button without select archiv follow error occur unsupport file type error messag chang archiv select upload step reproduc log axis2 administr consol click upload servic left navig pane click upload button without specifi archiv actual result follow error occur unsupport file type error messag display expect result error messag chang follow error occur archiv select upload',
#   0],
#  [' java2wsdl gener unknown namespac issu come user mail list http marc theaimsgroup com 115937715900004 java2wsdl gener unknown namespac http test xsd use current nightli servic class method sayhello return array simpl java bean hellobean run java2wsdl sayhello sayhellorespons namespac http aaa bbb type hellobean unknown namespac http test xsd bug axis2 std snapshot bin bin java2wsdl bat cn test testservice1 cp tn http aaa bbb tp xxx stn http aaa bbb type stp yyy sn testservice1 testservice1 wsdl gener wsdl like wsdl definit xmln soap12 http schema xmlsoap org wsdl soap12 xmln http http schema xmlsoap org wsdl http xmln mime http schema xmlsoap org wsdl mime xmln ns1 http aaa bbb type xmln xxx http aaa bbb xmln soap http schema xmlsoap org wsdl soap xmln wsdl http schema xmlsoap org wsdl targetnamespac http aaa bbb wsdl type xs schema xmln xs http www w3 org 2001 xmlschema xmln ax22 http test xsd targetnamespac http test xsd attributeformdefault qualifi elementformdefault qualifi xs element name hellobean type ax22 hellobean xs complextyp name hellobean xs sequenc xs element name ret1 type xs string xs element name ret2 type xs int xs element name ret3 type xs long xs element name ret4 type xs doubl xs element name ret5 type xs float xs element name ret6 type xs short xs element name ret7 type xs boolean xs sequenc xs complextyp xs schema xs schema xmln xs http www w3 org 2001 xmlschema xmln gen798 http test xsd xmln ax21 http aaa bbb type targetnamespac http aaa bbb type attributeformdefault qualifi elementformdefault qualifi xs element name sayhello xs complextyp xs sequenc xs element name var1 type xs string xs element name var2 type xs int xs element name var3 type xs long xs element name var4 type xs doubl xs element name var5 type xs float xs element name var6 type xs short xs element name var7 type xs boolean xs sequenc xs complextyp xs element xs element name sayhellorespons xs complextyp xs sequenc xs element name return maxoccur unbound type gen798 hellobean nillabl true xs sequenc xs complextyp xs element xs schema wsdl type',
#   0],
#  [' provid mechan obtain effect polici messag context need mechan obtain effect polici given messag messag context return org apach neethi polici instanc',
#   0],
#  [' endpointrefer serial deseri consolid endpointrefer class issu depend issu http issu apach org jira brows axis2 993 current endpoint refer serial deseri code exist four differ place endpointrefer addressingfinalinhandl addressingsubmissioninhandl addressingouthandl code consolid one place endpointrefer would greatli simplifi address handler patch follow',
#   0],
#  [' properti ws_addressing_vers current overload properti ws_addressing_vers current use indic address handler run base address namesapc defin properti address handler run base properti null would like chang semant properti indic address handler run base address namespac allow anoth handler secur handler abl specifi address handler run inbound messag handler tri today use properti neither address handler would run due overload semant patch follow',
#   0],
#  [' basic authent support work provid http basic authent support per jaxw specif section 10 secur',
#   0],
#  [' build maven tracker bug serv follow purpos keep peopl inform ongo effort prevent someon els start work topic possibl attract peopl start work collect depend relat bug like axis2 1128',
#   0],
# ...
#   0],
#  [' comment impala shell interact mode handl properli caus syntax error wrong result although impala shell allow singl line comment batch mode via option give unrecogn command error comment enter command prompt localhost 21000 foo unrecogn command localhost 21000 foo unrecogn command command shell allow comment way process sometim user run code might copi past rang line sometim user conduct interactiv experi might enter commentari impala shell session use script save session output log file includ comment request impala 191 ask impala shell allow style comment also',
#   0],
#  [' support comment common command shell oracl mysql databas support singl line multi line comment notat impala shell blah sql current give unrecogn command comment silent ignor exampl basic mysql sampl code http download mysql com doc world sql zip immedi give bunch unrecogn command error due mix comment top file regardless whether actual sql command syntax compat base pattern error messag seem like impala realli ignor whatev delimit might case spuriou messag actual encount',
#   0],
#  [' order give syntax error certain case queri work select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order vcf_po limit 100 queri fail syntax error select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order limit 100 error com cloudera impala common analysisexcept analysi except select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order limit 100 com cloudera impala analysi analysiscontext analyz analysiscontext java 195 com cloudera impala servic frontend createexecrequest frontend java 387 com cloudera impala servic jnifrontend createexecrequest jnifrontend java 119 caus com cloudera impala common analysisexcept order ordin refer select list com cloudera impala analysi selectstmt substituteordin selectstmt java 493 com cloudera impala analysi querystmt createsortinfo querystmt java 87 com cloudera impala analysi selectstmt analyz selectstmt java 154 com cloudera impala analysi analysiscontext analyz analysiscontext java 192 clear first column work',
#   0],
#  [' throw error default order limit reach default queri option set limit default_order_by_limit alreadi exist describ http ccp cloudera com display impala10betadoc languag refer howev case default limit set reach user need notifi limit reach',
#   0],
#  [' runtim state contain queri string runtim state someth like contain queri string extrem use debug core dump anoth way get run queri alreadi',
#   0],
#  [' issu s3 error messag recommend secret key url access id secret key embed impala config file like recommend attempt creat tabl s3 produc error messag mention emb set url specifi locat attribut localhost 21000 creat tabl sample_data_s3 like sample_data store parquet locat s3a impala demo sample_data error analysisexcept null caus illegalargumentexcept aw access key id secret access key must specifi usernam password respect s3a url set fs s3a awsaccesskeyid fs s3a awssecretaccesskey properti respect want peopl suppli set via config properti catch error issu differ messag mention properti name url method',
#   0],
#  [' clarifi creat tabl error messag long char varchar column current defin column length 32672 give error like localhost 21000 creat tabl varchar_million varchar 1000000 error analysisexcept varchar size must 32672 size set 1000000 localhost 21000 creat tabl char_million char 1000000 queri creat tabl char_million char 1000000 error analysisexcept char size must 32672 size set 1000000 size set busi make look like impala adjust size allow valu continu creat tabl statement realli bail base rang valu localhost 21000 show tabl like million queri show tabl like million fetch row 04 suggest reword error messag along line type size ld rang must 32672 also low number produc cryptic sort error localhost 21000 creat tabl char_million char queri creat tabl char_million char error analysisexcept syntax error line creat tabl char_million char encount expect integ liter seem confus peopl might think integ liter rather negat oper appli liter length zero give error messag localhost 21000 creat tabl char_million char queri creat tabl char_million char error analysisexcept char size must size set perhap case could use messag say valu must 32672 avoid user go trial error low high valu',
#   0],
#  [' issu distinct error messag unsupport subqueri syntax localhost 21000 select higher count million_numb select cast appx_median doubl million_numb union select lower count million_numb select cast appx_median doubl million_numb error analysisexcept unsupport statement contain subqueri select higher count appx_median million_numb select cast appx_median doubl appx_median million_numb union select lower count appx_median million_numb select cast appx_median doubl appx_median million_numb believ unsupport aspect union differ queri contain subqueri gener unsupport messag follow origin lengthi queri make hard figur fail differ case error could occur suggest make uniqu messag exampl error subqueri cannot use claus union queri low prioriti expect go',
#   0],
#  [' show time info shell command like see time info impala shell command compar perform queri etl oper howev use execut command like hdf df put giant_fil indic long took want see time command like use set shell seem like logic place show elaps time understand difficult implement due command go real impalad connect',
#   0],
#  [' throw away summari next success statement mind much non queri statement like use describ caus summari output previou queri discard look like even syntax error make summari unavail suggest keep summari around next statement least pass analysi check localhost 21000 select count billion_numb count 1000000000 localhost 21000 summar error analysisexcept syntax error line summar encount identifi expect alter comput creat describ drop explain insert invalid load refresh select show use valu caus except syntax error localhost 21000 summari error queri id found could retriev summari queri',
#   0],
#  [' quot argument pass use impala shell databas name parquet back parquet keyword great find name conflict use option parquet impala shell fail databas name get quot pass along use statement impala shell localhost parquet start impala shell without kerbero authent connect localhost 21000 server version impalad version cdh4 intern releas build b960fdb4fdf4d59bbe10855e92a8f36c778262e6 welcom impala shell press tab twice see list avail command copyright 2012 cloudera inc right reserv shell build version impala shell v1 cdh4 intern b960fdb built fri jun 20 19 51 13 pdt 2014 queri use parquet error analysisexcept syntax error line use parquet encount parquet expect identifi caus except syntax error quot done automat',
#   0],
#  [' reduc repetit parquet decim messag cdh see cdh localhost 21000 creat tabl t4 tinyint smallint int bigint boolean timestamp string float doubl decim decim decim 38 decim 38 15 store parquet error decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon tabl t4 actual creat think messag warn error sinc messag actual state name applic decim column repeat decim column add extra inform way limit messag one occurr per creat alter tabl',
#   0],
#  [' receiv report unknown queri id log info error messag see get report unknown queri id often benign sinc queri usual realli close cancel action bump vlog',
#   0],
#  [' add queri text query_profil page ad sql text query_profil page make commun debug info easier',
#   0],
#  [' upgrad apach common fileupload later', 0],
#  [' selectivefoldingfilt jena text current support accent fold jena text lucen provid asciifoldingfilt filter enabl search deja vu match liter d? vu data use nation librari finland finto fi skosmo fold much finnish alphabet addit latin ascii use letter ? fold ascii need lucen analyz configur exclud list someth like new selectivefoldingfilt string excludechar also configur via jena assembl like analyz support jena text also briefli discuss skosmo user mail list http group googl com msg skosmo user x3zr_urbqt0 q90 o_idaqaj appar norwegian problem discuss kinow initi code implement featur think turn pr fairli soon',
#   0],
#  [' add systemd unit file fuseki discuss user mail list could add systemd unit file fuseki make easier set systemd base linux instal make pr soon ping jneubert origin request',
#   0],
#  [' make top pom parent make pom top code tree parent pom modul merg jena project pom remov modul jena project',
#   0],
#  [' add dynamicdataset sdb support name queri sdb current support name queri ad dynamicdataset support resolv',
#   0],
#  [' improv graphutil oper consid rel graph size bulk graphutil oper addinto deletefrom could improv loop smaller graph differ algorithm depend whether sourc destin graph smaller',
#   0],
#  [' querybuild addfilt accept anyth string addfilt take claus construct creat filter string',
#   0],
#  [' command line tool run embed fuseki server run embed server use headless fuseki server without fuseki standard ui without admin function togeth static html page cover run fuseki2 sparql org',
#   0],
#  [' httpop switch use pool httpclient default default cach content complic big impact unsuspect client code cach lot larg item use ram',
#   0],
#  [' riot mainten post jena 1306 scope lot clear simplifi parser creation particular two set creat parser set profil chang set profil thing need make code control error handl control prefix part reader parser engin constructor pr 234 start roll earlier improv elepha made sens mainten bit bit look like becom work',
#   0],
#  [' bad runtim regex pattern print stacktrac runtim regex pattern mani mani log messag http list apach org thread html 0d6042871739323716346ebfff76e64ede7c39a52eacbc0ab17d6d3c 3cdev jena apach org 3e',
#   0],
#  [' except rewrap httpqueri mask error respons server sparql server respond request error 500 error tomcat error respons bodi provid detail inform went wrong respons inform includ underyl httpexcept mask faulti error handl code org apach jena sparql engin http httpqueri rewrap method specifi httpex root caus except httpex getcaus ensur respons bodi inform preserv',
#   0],
#  [' drop solr support jena text jena spatial discuss dev list propos drop solr support jena text jena spatial reason evid run document unit test specif solr whether work cannot easili verifi time gain featur ad jena text recent year multilingu index store liter valu variou special analyz upgrad lucen jena 1250 would probabl break sinc solr use depend lucen though due reason tell elasticsearch support jena text develop anuj kumar offer kind extern text index function solr support use offer fun look effect maintain code know anyon use whether even work heard user jena text solr long time recent exchang http comment gmane org gmane comp apach jena user 3369 could find user list 2013 end unclear whether user ever got work okay anoth thread http thread gmane org gmane comp apach jena user 8892 april may 2016 solr appar use discuss issu volunt actual clean get agreement',
#   0],
#  [' separ modul elasticsearch elasticsearch quit larg separ modul mean inclus non inclus fuseki control easili pr 245',
#   0],
#  [' spatial queri slow larg databas load geonam jena spatial queri take 3s execut queri prefix spatial http jena apach org spatial prefix rdf http www w3 org 2000 01 rdf schema select distinct place place spatial intersectbox 32 55668 117 12865 32 56668 117 13865 data download http drive googl com file 0b fwypjyt1goyvvizf9rouxzclk view usp share small dataset queri execut 200m fast notic access lucen index directli queri also fast 20m issu may relat po process lucen result',
#   0],
#  [' execut cmd line queri insid transact command line arq queri put read transact around queri execut dataset support transact dataset may requir transact use',
#   0],
#  [' rdfconnect rdfconnect api bring togeth part sparql queri updat graph store protocol',
#   0],
#  [' make resultset closeabl current queryexecut close done work resultset mean write function return resultset expect queryexecut properli close problem fix like make resultset interfac extend closableiter probabl autoclos fall back ad close case plan caus someth aw happen put refer queryexecut probabl refer autoclos streamresultset streamresultset close implement deleg otherwis noth resultsetstream close get end make sure close relev queryexecut element idempot crash doubl close otherwis behavior follow later qe close could caus troubl make close op resultsetmem point punish user use use resultsetmem autoclos put javadoc resultsetrewind self close resultset rewind close hit end think exactli resultsetpeek rewind get blindsid corner condit isclos method resultset would call attent fuzzi involv volunt',
#   0],
#  [' revis graph capabl graph capabl origin featur jena reflect variat implement capabl make sens nowaday unclear jira mainten see also discuss dev http list apach org thread html 9d5a82d701b84ec5397e4441a593283ebf7af4bf8619c495d2d43d01 3cdev jena apach org 3e dec 2016',
#   0],
#  [' make rdf primit serializ alway use jena handl rdf data apach spark howev want store result rdd data ex rdd tripl binari format call rdd saveasobjectfil method rdd saveasobjectfil requir java io serializ interfac see follow code http github com apach spark blob v1 core src main scala org apach spark rdd rdd scala l1469 http github com apach spark blob v1 core src main scala org apach spark util util scala l79 l86 see rdd saveasobjectfil call util serial method util serial method requir rdd wrap object implement java io serializ interfac exampl want save rdd tripl object tripl must implement java io serializ implement java io serializ think improv usabl apach spark',
#   0],
#  [' enhanc sdbload cover quad format trigger bulk loader print progress', 0],
#  [' support mariadb jdbc driver mariadb jdbc compat mysql jdbc driver differ licens mariadb jdbc driver lgpl mysql jdbc driver gpl special foss except addit mariadb jdbc driver respons jdbc mysql url support driver two part mariadb explicitli chosen sdb sdbtype registr mariadb map org mariadb jdbc driver ideal build right jdbc url case url explicitli provid part setup mysql mariadb jdbc driver classpath treat special case load jdbc driver look mysql classnam com mysql jdbc driver fail code also look org mariadb jdbc driver point jena sourc binari ship either jdbc driver',
#   0],
#  [' improv tokenizertext warn error handl put place structur warn token error enabl need test see knock effect ideal combin parser level error recoveri see also email discuss user nov 2016 http list apach org thread html 0f16e1e124abde11dbf40a65e9858a9fadd5fb4d67bffc76fd528a1a 3cuser jena apach org 3e',
#   0],
#  [' improv assembl error report target assembl exist', 0],
#  [' limit number outstand write transact tdb tdb journal grow due write back block long run reader success overlap short read mani updat user email http list apach org thread html 99b01f1dc7af86e0832279a85da6963985fc9f1f2c36d3c3969aaeb1 3cuser jena apach org 3e may caus effect accumul layer wrapper consum heap 300 time lock new transact wait flush journal mani layer',
#   0],
#  ...]

# %%
binary_class_dataset
# Out:
# [[' anoth blueprint sampl contribut day test blueprint mbean gener complex blueprint sampl sampl user learn defin nest compon blueprint xml run sampl besid osgi framework bundl requir coreopt mavenbundl groupid org apach felix artifactid org apach felix configadmin versionasinproject coreopt mavenbundl groupid org apach felix artifactid org apach felix eventadmin versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log api versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log servic versionasinproject coreopt mavenbundl groupid org apach ari blueprint artifactid org apach ari blueprint versionasinproject coreopt mavenbundl groupid org apach ari artifactid org apach ari util coreopt mavenbundl groupid org apach ari jmx artifactid ari jmx blueprint versionasinproject',
#   0],
#  [' blueprintcontainerimpl add info log blueprint contain creat look issu reload ari blueprint need turn debug log variou packag see goe miss also normal usag info log log blueprint contain creat eg blueprintcontainerimpl code code eventdispatch blueprintev new blueprintev blueprintev creat getbundlecontext getbundl getextenderbundl state state creat code suggest add info log detail blueprint contain creat peopl easier spot contain creat log need enabl debug log look blueprinteventdispatch send even creat',
#   0],
#  [' creat basic build structur ari jpa compon creat basic structur jpa compon ari',
#   0],
#  [' ad back home link teh blog sampl', 0],
#  [' documant blog sampl run code organis add web page document', 0],
#  [' excess io instal subsystem initi root subsystem notic activ subsystem core bundl take long time start subsystem core lot io done establish constitu root subsystem particular environ 120 bundl bundl end constitu root subsystem call org apach ari subsystem core intern subsystem getrootsubsystem deploy manifest root subsystem rewritten constitu detect file content get progress larger constitu ad end 121 time whole file get written final content file end around 14 kb two observ bufferedoutputstream use write deploy manifest sinc file grow sever kb size would optim use buffer output stream avoid write persist deploy manifest success instal done end write complet deploy manifest',
#   0],
#  [' abl easili use blueprint insid war servlet contain use blueprint noosgi servletcontextlisten boot blueprint xml file initi patch submit pull request first cut basic let war servlet engin act like blueprint osgi sens jar includ blueprint xml file meta inf blueprint xml differenti osgi base configur servletcontextlisten use find blueprint xml file classpath depend jar war boot everyth',
#   0],
#  [' integr version plugin subsystem modul releas', 0],
#  [' updat ari jpa implement osgi support hibern fork ari jpa updat jpa need test bed spec yet current final draft hope soon vote fork use hibern current implement api creat pull request work case want start point whenev begin support pretti simplist updat pom manifest ad un implement method etc sever place featur new may need implement howev may need throw unsupport pull request http github com apach ari pull feel free take leav',
#   0],
#  [' revisit use coordin order take advantag deploy manifest optim ari 1034 introduc optim save deploy manifest delay coordin present subsystem oper affect deploy manifest revist make use coordin order take advantag chang',
#   0],
#  [' org apach ari subsystem core intern activ need improv current org apach ari subsystem core intern activ class org apach ari subsystem core intern subsystemresolverhookfactori class curiou code follow activ new subsystem throw subsystemexcept addingservic method suggest follow write overrid public synchron object addingservic servicerefer object refer object servic bundlecontext getservic refer servic instanceof idirectoryfind finder add idirectoryfind servic return servic els servic instanceof repositori repositori add repositori servic return servic els servic instanceof coordin coordin null coordin coordin servic els servic instanceof regiondigraph regiondigraph null regiondigraph regiondigraph servic els servic instanceof resolv resolv null resolv resolv servic els servic instanceof modelledresourcemanag modelledresourcemanag null modelledresourcemanag modelledresourcemanag servic activ return servic subsystemresolverhookfactori class constructor never seen follow explicitli throw npe subsystem null throw new nullpointerexcept miss requir paramet subsystem suggest better use runtimeexcept illegalargumentexcept',
#   0],
#  [' publish singl interfac better integr transactionmanag low level compon integr geronimo connector librari quit hard use ari transact manag interfac expos expos singl interfac inherit need one eas work lot',
#   0],
#  [' releas latest org apach ari jndi core http svn apach org repo asf ari trunk jndi jndi core src main java org apach ari jndi objectfactoryhelp java need follow code mehtod getobjectinstanceviacontextdotobjectfactori class factori instanceof dirobjectfactori logger log level fine dirobjectfactori final dirobjectfactori dirfactori dirobjectfactori factori result dirfactori getobjectinst obj name namectx environ attr http src springframework org svn spring ldap trunk core src main java org springframework ldap core support defaultdirobjectfactori java public object getobjectinst object obj name name context namectx hashtabl environ throw except return null',
#   0],
#  [' add way use properti placehold defin filter servic refer idea defin ext filter attribut would valuemetadata properti substitut would take place placehold',
#   0],
#  [' creat either synchronis entiti manag proxi creat entiti manag request use apach ari contain manag transact jta hibern persist start multipl thread read databas without transact transact annot ommit get follow stacktrac org hibern assertionfailur possibl non threadsaf access session org hibern engin intern twophaseload initializeent twophaseload java 130 org hibern loader loader initializeentitiesandcollect loader java 1103 org hibern loader loader processresultset loader java 960 org hibern loader loader doqueri loader java 910 org hibern loader loader doqueryandinitializenonlazycollect loader java 341 org hibern loader loader dolist loader java 2516 org hibern loader loader dolist loader java 2502 org hibern loader loader listignorequerycach loader java 2332 org hibern loader loader list loader java 2327 org hibern loader hql queryload list queryload java 490 org hibern hql intern ast querytranslatorimpl list querytranslatorimpl java 355 org hibern engin queri spi hqlqueryplan performlist hqlqueryplan java 195 org hibern intern sessionimpl list sessionimpl java 1247 org hibern intern queryimpl list queryimpl java 101 reason got except non transact mode inject entitymanag implement use differ request multipl thread unfortun entitymanag thread safe refactor code inject entitymanagerfactori instead sinc entitymanagerfactori thread safe creat entitymanag method programmat ari stand point abl improv order eas pain creat synchron entiti manag proxi creat entiti manag request proxi would probabl follow creat entitymanag perform request close entitymanag',
#   0],
#  [' inject support fluent setter method pleas look support fluent setter current ari reflectionutil allow method return type void seem restrict also spring support see section http static springsourc org spring doc releas spring framework refer html new html',
#   0],
#  [' provid common schema xml namespac schema use xml namespac thing xml lang xml base etc need import http www w3 org xml 1998 namespac blueprint could provid namespac handler namespac avoid bunch differ bundl add namespac handler',
#   0],
#  [' introduc blueprintextenderservic simplifi manag blueprintcontain code easi creat blueprintcontain code blueprintextend main piec code deal contain propos introduc blueprintextenderservic make straght forward interest consum creat use blueprintcontain patch commun review follow anoth jira support specif use case open shortli',
#   0],
#  [' introduc blueprint web osgi modul exist blueprint web modul depend non osgi blueprint modul case necessari abl access creat blueprintcontain given bundl way blueprint web osgi environ exampl custom servlet depend osgi awar blueprint servletcontextlisten listen use propos blueprintextenderservic creat blueprintcontain set servletcontext attribut custom servlet check blueprintcontain extract requir applic compon',
#   0],
#  [' updat blueprint core ari modul blueprint core releas consist upgrad ari modul use blueprint core version',
#   0],
#  [' support blueprintnullproxi blueprint rfc http github com osgi design tree master rfc rfc0184 add concept null proxi support reason easili requir updat ari proxi api',
#   0],
#  [' use header resolv depend bundlestatembean bundlestatembean getimportedpackag long bundleid getrequiredbundl long method resolv depend use iter bundl framework perform method improv first check manifest header use valu packageadmin queri note bundl use dynamicimport still requir full iter',
#   0],
#  [' abil disabl blueprint schema valid via system properti ari blueprint code allow schema valid disabl ad bundl symbol name direct _blueprint ari xml valid false_ unfortun must done bundl contain blueprint descriptor inclus ari blueprint jar also contain blueprint descriptor would nice disabl schema valid global bundl deploy osgi contain perform impact valid xsd embed devic valid xsd quiet expens necessari product code blueprint code alreadi check direct blueprintcontainerimpl code string xmlvalidationdirect headerpars pathel path get getdirect blueprint ari xml valid xmlvalidationdirect null logger debug xml valid direct xmlvalidationdirect xmlvalid boolean parseboolean xmlvalidationdirect code cheer micha',
#   0],
#  [' allow refer refer filter servic multipl interfac relat ari 1140 servic regist multipl class interfac howev refer use singl interfac lookup case would good provid via ext namespac way refer implement addit interfac also restrict refer servic implement extra interfac',
#   0],
#  [' ari subsystem use org osgi servic repositori repositori interfac problemat ari subsystem work osgi repositori provis resourc requir osgi subsystem spec howev implement also implement repositori interfac provid repositori facad thing like felix repositori esa content thing look relev import packag header see defin follow org osgi servic repositori version problemat sinc repositori interfac provid type henc version contain new method use repositori break current subsystem implement local repositori facad implement repositori interfac chang version rang good idea either limit integr repositori servic make subsystem work repositori implement want keep import org osgi servic repositori version tact need chang subsystem implement way continu work repositori interfac move new method ad',
#   0],
#  [' add support creat non xa datasourc actual need xadatasourc get handl transact jdbc might use one abstract layer configur either non xa datasourc xadatasourc way capabl pool error handl may gener way provid specif driver class inform benefit uniqu approach would get kind datasourc configur way top geronimo core librari transact flag none local xa might use distinct',
#   0],
#  [' esa maven bundl without packag type esa case pom packag type cannot esa bundl add pom artefact subsystem scenario pom packag type bundl maven bundl plugin bundl suppos packag subsystem depend',
#   0],
#  [' jmx whiteboard also accept interfac end mxbean mbean jmx whiteboard requir mbean servic implement interfac name class mbean port system use ari whole lot mxbean instead regular mbean get ignor mistaken function mxbean subset mbean think would make sens ari accept mxbean tri local trunk seem trick guy gal interest trivial patch',
#   0],
#  [' make subsystem independ applic model modelledresourcemanag option packag depend',
#   0],
#  [' upgrad asm order support java8 ari proxi ari spifli uprad asm5', 0],
#  [' upgrad proxi impl asm java support ari proxi work java sinc depend asm support java current blocker work karaf java karaf contain ari proxi impl upgrad asm requir chang super call ari subclass asm class tri local build ari proxi impl snapshot chang result seem ok karaf larger part issu ari side depend prehistor version pax exam depend pax runner addit configur tweak ari support java either abl run proxi integr test',
#   0],
#  [' remov pax exam depend org apach ari testsupport unit like describ http mail archiv apach org mod_mbox ari dev 201405 mbox 3c5370e1ea 9040008 40die schneider net 3e propos remov pax exam depend org apach ari testsupport unit reason think make sens testsupport use mani ari project mani need pax exam depden depend bind project particular pax exam version increas coupl pax exam need two class test support extraopt abstractintegrationtest extraopt realli necessari newer pax exam version featur avail directli pax exam dsl abstractintegrationtest use pax exam inject pax exam replac javax inject depend necessari anymor far know mean need new major version testsupport remov public class provid patch',
#   0],
#  [' updat transact integr test pax exam', 0],
#  [' updat ari proxi integr test pax exam', 0],
#  [' updat jndi integr test pax exam', 0],
#  [' web urlhandl depend blueprint blueprint context org apach ari web urlhandl project regist two simpl servic done way use plain java bundleactiv get rid unnecessari blueprint depend',
#   0],
#  [' maven plugin creat ari applic archiv would nice plugin maven creat ari applic archiv someth similar maven ear plugin maven war plugin ari applic',
#   0],
#  [' forward javax persist jdbc properti datasourcefactori alreadi possibl refer datasourc persist xml defin javax persist jdbc driver instead jndi datasourc implement look datasourcefactori servic problem foward three properti factori url user password usabl derbi datasourcefactori provid ops4j datasourc requir databasenam work url user password would like chang code datasourcefactorydatasourc accept complet properti object object fill persist unit copi properti start javax persist jdbc remov prefix allow configur datasourcefactori requir hope misus javax persist jdbc properti namespac good idea pleas speak',
#   0],
#  [' convert applicationmetadatamanag simpl factori improv applic javadoc tidi loos end ari 89 applicationmetadatamanag need facotri api javadoc could improv',
#   0],
#  [' add connect valid featur jdbc ari transact jdbc lack support connect valid datasourc pool',
#   0],
#  [' switch ejb model itest pax exam', 0],
#  [' use system bundl track namespac handler bundl blueprint implement current use bundlecontext track namespac handler caus issu namespac handler contain subsystem one approach support namespac handler contain applic subsystem would blueprint use system bundl context track namespac handler blueprint also use org apach ari util tracker recursivebundletrack track bundl blueprint compon recursivebundletrack understand composit know recurs track blueprint contain composit bundl make depend recursivebundletrack option fallback use system bundl context track blueprint would allow support subsystem blueprint',
#   0],
#  [' fix requir provid servic proxymanag', 0],
#  [' npe thrown getbundlecontextact hi current investig npe thrown getbundlecontextact stack trace java lang nullpointerexcept org apach ari subsystem core intern getbundlecontextact run getbundlecontextact java 35 org apach ari subsystem core intern getbundlecontextact run getbundlecontextact java 22 java secur accesscontrol doprivileg accesscontrol java 273 org apach ari subsystem core intern basicsubsystem getbundlecontext basicsubsystem java 186 snip know caus look getbundlecontextact line 35 contain nest method invoc one return null like submit suggest follow patch split line add basic error check index getbundlecontextact java getbundlecontextact java revis 1607078 getbundlecontextact java work copi 16 16 import java secur privilegedact import java util enumset import org eclips equinox region region import org osgi framework bundl import org osgi framework bundlecontext import org osgi servic subsystem subsystem state 26 15 28 23 subsystem subsystem overrid public bundlecontext run enumset state install_fail state uninstal contain subsystem getstat return null basicsubsystem subsystem util findscopedsubsysteminregion subsystem return subsystem getregion getbundl regioncontextbundlehelp symbolicname_prefix subsystem getsubsystemid regioncontextbundlehelp version getbundlecontext region region subsystem getregion region null return null cover call regiondigraph getregion name return null bundl bundl region getbundl regioncontextbundlehelp symbolicname_prefix subsystem getsubsystemid regioncontextbundlehelp version bundl null null bundl return null return bundl getbundlecontext',
#   0],
#  [' allow perserservic pars success namespac handler miss blueprint parserservic expos blueprint parser bundl great allow bundl model reason blueprint depend parserservic current fail componentdefinitionexcept custom namespacehandl use within compon xml file pars custom namespacehandl servic current regist becom pain scenario tri reason depend group bundl one bundl provid namespacehandl servic use runtim bundl group exampl osgi subsystem may instal group bundl content subsystem implement ari attempt model blueprint depend bundl resourc actual instal start bundl done use blueprint parserservic alway fail blueprint xml use custom namespac fail model correctli ultim result subsystem instal failur would nice parserservic could configur ignor miss namespacehandl continu model basic blueprint xml one way accomplish would framework properti configur ignor namespac miss use parserservic chang behavior parserservic intern usag parser implement blueprint core also chang current behavior parserservic unless option ignor enabl explicitli anoth option chang parserservic api somehow pass option ignor unknown namespacehandl unfortun side effect explod api parserservic mani layer built top parserproxi modelledresourcemanag get use ari subsystesm perhap correct thing comfort chang much api usecas global switch simpli enabl option ignor miss namespacehandl good enough usag other want add api allow client api make choic fine would prefer done someon familiar overal api',
#   0],
#  [' allow extern access felix osgi adapt org apach ari subsystem obr intern hi current write code access felix repositori allow interact repositori via osgi interfac someth ari insid org apach ari subsystem obr intern packag number class provid abil adapt osgi felix felix osgi class question felixcapabilityadapt java felixproperti java felixrepositoryadapt java felixrequirementadapt java felixresourceadapt java osgicapabilityadapt java osgicontentcap java osgiidentitycap java osgirequirementadapt java osgiresourceadapt java rather invent wheel take copi would like propos class move packag subsequ export extern use scan import statement none look refer ari intern class believ simpl refactor would requir',
#   0],
#  [' entitymanagerfactorymanag remov tri creation entitymanagerfactori bundl resolv event entitymanagerfactorymanag alreadi mention ari 1160 see benefit tri creat entitymanagerfactori bundl resolv event time bundl resolv bundl context still initi tri creation entitymanagerfactori like fail hibern eclipselink implement fail lookup datasourc servic confus user stack trace entitymanagerfactori creat tick later bundl activ event call registerentitymanagerfactori method patch attach',
#   0],
#  [' remov blueprint depend ari transact jm make xbean depend option depend blueprint provid activ like ari transact jdbc',
#   0],
#  [' use gener capabl requir servic', 0],
#  [' add blueprint maven plugin recent creat maven plugin gener blueprint xml cdi jee spring annot http github com cschneider blueprint maven plugin make differ blueprint annot support alreadi got ari blueprint annot follow xml style bind exact bean id annot use default bind simpli type much simpler manag line spring autowir cdi inject still also allow bind name use name ari blueprint annot process runtim creat xml cover plugin hand work build time runtim instal exist contain run blueprint addit dep need plugin use standard cdi jee annot standard servic pax cdi annoat peopl use style transit real cdi quit easili peopl jee background also feel home style plugin also support spring annot like autowir compon valu allow fast migrat spring blueprint fact use quit big custom project case sampl applic creat exampl applic show follow featur intern wire contain manag jpa transact use offer osgi servic http github com cschneider karaf tutori tree master tasklist cdi',
#   0],
#  [' improv log output destroy blueprintcontain blueprintextend destroycontain method logger info destroy blueprintcontain bundl bundl getsymbolicnam besid symbol name also display version inform perhap best consid log output use bundl getsymbolicnam includ version',
#   0],
#  [' refactor blueprint nshandler class nshandler quit larg especi decor method long difficult understand fast plan extract emfservic ref creation separ class extract part method',
#   0],
#  [' support type configur properti placehold possibl configurationadmin put complex type configur object list array return configur ari placehold get crazi tri convert retriev valu string back type requir bean',
#   0],
#  [' name unnam maven project sourc tree build ari sourc stumbl upon follow info unnam org apach ari jpa jpa contain testbundl bundl incub snapshot success 317 info unnam org apach ari jpa jpa contain itest jar incub snapshot success 12 326 miss proper name possibl fals assumpt default name maven project proper',
#   0],
#  [' noosgi blueprintcontextimpl accept custom namespac handler set', 0],
#  [' ant esa taskdef ari user would like ant base task would gener enterpris servic archiv esa',
#   0],
#  [' support produc annot blueprint maven plugin blueprint creat bean use factori ref factori method jee done use produc anntat factori support produc annot blueprint maven plugin translat gener two bean code result xml singleton public class myfactorybean produc public myproduc creat return new myproduc messag public class myproduc privat string messag public myproduc string messag messag messag public string getmessag return messag bean id myfactorybean class org apach ari blueprint plugin test myfactorybean ext field inject true bean bean id myproduc class org apach ari blueprint plugin test myproduc ext field inject true factori ref myfactorybean factori method creat bean',
#   0],
#  [' support special blueprint bean like blueprintbundlecontext blueprint defin special bean id return defin instanc blueprintbundlecontext bundlecontext blueprintbundl bundl blueprintcontain blueprintcontain blueprintconvert convert class support maven blueprint plugin',
#   0],
#  [' subsystem command ari subsystem user would prefer ari subsystem implement provid subsystem instal command would help user standard bundl oper instal start stop updat uninstal esa archiv',
#   0],
#  [' support env xxx variabl substit environ variabl', 0],
#  [' upgrad blueprint test pax exam', 0],
#  [' upgrad geronimo transact manag', 0],
#  [' upgrad applic pax exam', 0],
#  [' sampl implement promis api osgi r6 asynchron servic osgi asynchron servic rfc 206 defin new promis api releas r6 framework 100kb patch sampl implement promis api creat scratch use api defin rfc 206 aim quickli creat conform implement best implement code undoubtedli improv contain unit test may miss test case formal compat test derek baum paremu com',
#   0],
#  [' basic implement async servic osgi asynchron servic rfc 206 provid use tool make asynchron invoc osgi servic ari implement servic abl contribut basic function complet version',
#   0],
#  [' reduc memori alloc org apach ari blueprint proxi collabor class case intens usag memori cpu overhead org apach ari blueprint proxi collabor easi elimin stack thread safeti overhead replac arraydequ stack use singl thread case interceptor make sens alloc time stack object refer set null static immut empti stack valu',
#   0],
#  [' introduc namespac annot appli blueprint parser compon namespacehandl interfac list namespac handler support make difficult autom registr handler non osgi context namespac annot provid option mechan namespacehandl advertis list support namespac help discov handler non osgi context also introspect osgi need',
#   0],
#  [' updat blueprint web servletcontextlisten option regist namespacehandl option use blueprintnamespacehandl context paramet code xml web app context param param name blueprintloc param name param valu web inf bean xml param valu context param context param param name blueprintnamespacehandl param name param valu param valu context param listen listen class org apach ari blueprint web blueprintcontextlisten listen class listen rest web app web app code option check meta inf blueprint handler class resourc handler resourc list one namespacehandl class exampl noformat noformat web xml look much simpler code xml web app context param param name blueprintloc param name param valu web inf bean xml param valu context param listen listen class org apach ari blueprint web blueprintcontextlisten listen class listen rest web app web app code',
#   0],
#  [' allow use blueprint annot configur file simultan current possibl mix blueprint annot configur file bundl case use tx enabl annot autzh enabl necessari use configur file side annot closer code would great allow use blueprint annot configur file simultan',
#   0],
#  [' allow defin bean id servic ref want refer two servic classnam interfac differ packag current get bean id deriv sole classnam interfac need way defin bean id case suitabl way enabl name qualifi osgiservic ref',
#   0],
#  [' improv inform provid servic unavail tri use applic see error similar follow 31 01 10 17 58 14 166 gmt 00000011 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop persist java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000012 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop warehous java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000013 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop admin java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 31 01 10 17 58 14 166 gmt 00000011 blueprintcont org apach ari blueprint contain blueprintcontainerimpl run unabl start blueprint contain bundl com ibm ws eba exampl onlineshop search java util concurr timeoutexcept org apach ari blueprint contain blueprintcontainerimpl run blueprintcontainerimpl java 270 java util concurr executor runnableadapt call executor java 453 java util concurr futuretask sync innerrun futuretask java 315 java util concurr futuretask run futuretask java 150 java util concurr scheduledthreadpoolexecutor scheduledfuturetask access 301 scheduledthreadpoolexecutor java 98 java util concurr scheduledthreadpoolexecutor scheduledfuturetask run scheduledthreadpoolexecutor java 207 java util concurr threadpoolexecutor worker runtask threadpoolexecutor java 886 java util concurr threadpoolexecutor worker run threadpoolexecutor java 908 java lang thread run thread java 736 current order diagnos gone wrong necessari turn trace inform provid necessari turn trace',
#   0],
#  [' remov codehaus repo add ops4j snapshot repo', 0],
#  [' upgrad maven releas plugin', 0],
#  [' updat parent', 0],
#  [' noosgi simplenamespacehandlerset tri resolv rel schema refer', 0],
#  [' avoid use ari util eclipselink adapt', 0],
#  [' upgrad geronimo transact manag', 0],
#  [' entitymanag reus seri coordin call consid scenario blueprint servic jpa code find return em find void delet em remov code blueprint bean inject call method within transact code transact b1 find entiti return find em find delet entiti attach code reason method bean proxi follow way code emsuppli precal emsuppli get find delet emsuppli postcal code method call get em find one em delet anoth one entiti manag within first em second em share transact within singl thread singl method call pleas also note transact could jta use differ unit singl transact scenario bundl a1 a2 a3 persist jpa expos entiti servic domain modul bundl a1 a2 a3 use differ schema databas differ unit name bundl b1 b2 b3 rest servic use entiti servic transact separ domain logic busi logic b1 b2 b3 use method a1 a2 a3',
#   0],
#  [' work exampl transact annot attach work exampl code transact annot place improv inlin bean scan beanmetadata null case one without id servic bean servic',
#   0],
#  [' basicsubsystem use subsystem instal process factor time faster problem poor perform instal subsystem contain 200 subsystem instal perform analys subsystem instal process notic basicsubsystem work lot manifest instead pre calcul data use lot use pre patch version basicsubsystem subsystem instal 200 run subsystem could take minut use patch version pre calcul highli use data new subsystem manifest deploy manifest set could bring 10 second pre calcul data highli use',
#   0],
#  [' perform improv findprovid method systemrepositori class two improv patch applic subsystem process method applic subsystem share capabl think work like mayb wrongli interpret specif process constitu store set process encount differ subsystem share across featur use 60 featur share bundl use process 60 time',
#   0],
#  [' support coordin trigger transact marker new jpa compon use coordin manag lifecycl jpa entitymanag blueprint transact support creat coordin transact marker allow jpa entitymanag control lifecycl larger dao method exampl servic method call sever dao method mark transact creat coordin method close entitymanag whole servic method servic method need transact annot txtype support case coordin start em lifecycl declar use annot without perform impact transact',
#   0],
#  [' add switch gener annot base style jpa', 0],
#  [' remov remain nl usag except log messag use nl support remov rest unifi handl',
#   0],
#  [' allow jta annot configur transact ari transact blueprint differ way configur transact xml bean level use wildcard xml bundl level use wildcard ari transact annoat jta standard transact annot code need work option new major version plan allow jta style make code well document consider smaller',
#   0],
#  [' provid option disabl provis depend instal time problem subsystem specif state depend subsystem must instal order attain instal state requir depend found instal must fail function describ order achiev fail fast function environ cannot support depend subsystem reject right away howev deploy situat valuabl delay instal depend exampl may wish independ simultan instal suit subsystem whose content interleav depend current possibl local repositori one subsystem avail other resourc avail other becom part system repositori assum compat share polici instal state acquir meantim subsystem fail instal three potenti workaround issu none may accept particular subsystem consum provid content part remot repositori note would requir subsystem content header comput subsystem provid implement packag subsystem singl esa make use parent child relationship manag instal order manual note would handl case circular depend solut allow independ simultan instal multipl subsystem interleav content depend thu give deploy flexibl desir propos solut custom direct introduc apach ari provis depend possibl valu instal resolv indic time depend provis occur default valu instal result current behavior direct may specifi part subsystem type header valu resolv indic depend provis instal time rather step occur subsystem resolv typic happen part start process subsystem apach ari provis depend resolv remain instal state start indic administr program monitor subsystem via servic registri subsystem yet depend provis subsystem start transit instal instal occur today assum provis depend succe subsystem immedi transit resolv state proceed normal state transit apach ari provis depend start instal void instal void instal install_fail uninstal uninstal instal fail reason depend provis start instal instal resolv resolv start activ instal instal provis depend fail instal instal resolv instal runtim resolut fail instal instal resolv resolv start resolv start fail child scope subsystem inherit apach ari provis depend valu first scope ancestor unless explicitli overridden unscop subsystem alway inherit apach ari provis depend valu first scope ancestor may overrid valu root subsystem alway valu apach ari provis depend instal altern solut make local repositori instal subsystem avail instal subsystem specif allow local repositori regist repositori servic although explicitli address possibl particular implement share intern nevertheless intent spec seem clear assum subsystem provid desir content share other potenti issu propos solut break contract instal method specifi subsystem ariessubsystem interfac requir either return subsystem instal state instal fail except howev assum explicit declar apach ari provis depend direct valu resolv grant implement permiss altern would return subsystem instal state even though none depend instal howev would also violat specif may confus third parti applic monitor subsystem servic via registri subsystem may one parent one scope parent mean addit parent alway featur unscop subsystem question apach ari provis depend inherit work multipl parent conflict valu simplifi assumpt would featur may overrid valu scope parent impli featur fail instal contain valu apach ari provis depend conflict scope subsystem within region test case set subsystem interleav content depend abl independ simultan success instal start subsystem apach ari provis depend resolv instal state success instal subsystem apach ari provis depend resolv avail servic success instal subsystem apach ari provis depend resolv depend instal success instal subsystem apach ari provis depend resolv undergo follow state transit start instal instal resolv resolv start activ subsystem apach eari provis depend resolv depend instal success start subsystem apach ari provis depend resolv install_fail state unsuccess instal subsystem apach ari provis depend resolv avail servic unsuccess instal subsystem apach ari provis depend resolv instal state depend cannot provis invok start method 10 subsystem fail inst ...
#   0],
#  [' comput requir filter resourcehelp match requir capabl often use method resolut current recomput requir filter call measur use test scenario develop part ari 1357 time took instal 50 featur measur featur consist 10 bundl plu one applic featur share 10 bundl bundl export uniqu packag applic consist 10 uniqu bundl bundl import packag offer contain featur baselin averag time instal 50 featur 67 second abstractrequir lazili comput requir filter ask first time subsequ call return alreadi comput valu resourcehelp ask whether requir instanc abstractrequir ask filter directli filter comput modif averag time instal 50 featur 46 second 31 improv',
#   0],
#  [' basiccap take advantag effect immut capabl current given alreadi exist capabl construct basiccap make copi attribut direct realli necessari sinc properli implement capabl effect immut requir osgi api profil show basiccap capabl resourc take 1550 ms total time optim longer regist sampl time 50 ms basiccap capabl resourc simpli reus alreadi exist effect immut attribut direct map provid capabl',
#   0],
#  [' provid effici implement local content repositori measur use new test scenario help flush bottleneck local content repositori time took instal applic measur applic consist 200 bundl half bundl export 50 packag half bundl import 50 packag give total 5000 requir 5000 capabl averag time across trial 13915 ms averag time across trial 14628 ms averag time across trial 14196 ms averag time across trial 13905 ms averag time across trial 14021 ms 14133 averag time across trial 7781 ms averag time across trial 7782 ms averag time across trial 8085 ms averag time across trial 7850 ms averag time across trial 7971 ms 7893 44 overal improv obtain subsystem region took 2254 ms 14 cach region context bundl use perform region lookup effort longer regist profil 50 ms sampl period find provid local repositori took 2260 ms 15 ad capabl set took 747 ms ask whether resourc content took 2152 ms 16 answer use exist content resourc set rather content header effort longer regist profil 50 ms sampl period find provid content repositori took 4510 ms 28 ad capabl set took 49 ms',
#   0],
#  [' add structur option blueprint xml valid featur current xml valid perform blueprint bean file default one disabl valid set blueprint ari xml valid fals avail option either full valid valid use case practic disabl datatyp valid keep structur valid request add option pass appropri errorhandl valid instanc datatyp specif valid error ignor',
#   0],
#  [' use capabl set calcul subsystem depend measur use beef version test ari 1394 time took instal applic measur applic consist 300 bundl 200 bundl export 50 packag 100 bundl import 50 packag give total 5000 requir 10 000 capabl 100 export bundl serv prefer provid calcul depend took 6728 ms 43 make use capabl set took 2005 ms 18 baselin averag time across trial 13841 ms averag time across trial 13820 ms averag time across trial 13982 ms averag time across trial 13599 ms averag time across trial 13782 ms 13804 dependencycalcul use capabl set averag time across trial 9923 ms averag time across trial 10247 ms averag time across trial 10180 ms averag time across trial 10212 ms averag time across trial 10442 ms 10200 26 overal improv',
#   0],
#  [' use capabl set prefer provid repositori measur use test ari 1396 time took instal applic measur applic consist 300 bundl 200 bundl export 50 packag 100 bundl import 50 packag give total 5000 requir 10 000 capabl 100 export bundl serv prefer provid find provid prefer provid repositori took 3305 ms 25 make use capabl set took 948 ms baselin averag time across trial 12974 ms averag time across trial 12597 ms averag time across trial 12760 ms averag time across trial 12573 ms averag time across trial 12339 ms 12648 prefer provid repositori use capabl set averag time across trial 10917 ms averag time across trial 10562 ms averag time across trial 10743 ms averag time across trial 10718 ms averag time across trial 10471 ms 10682 15 improv',
#   0],
#  [' make sure bundl goe graceperiod servic need jpa present current coordin well entitymanag servic inject use manual creat servic proxi problem stop blueprint start user context way jpa enabl bean start even prerequisit yet present lead call block runtim servic timeout error report also bad know someth went wrong first call timeout idea use correct blueprint metadata servic ref make blueprint go graceperiod servic present diag command also show miss current approach beanprocessor support approach se need switch componentdefinitionregistryprocessor recommend guillaum nodet',
#   0],
#  [' add karaf itest test exampl', 0],
#  [' switch namespac namespac enabl element like jpa instal togeth old transact bundl support smooth transit',
#   0],
#  [' allow configur code gener base namespac idea configur gener code specifi namespac use configur look like namespac namespac http ari apach org xmln jpa v2 namespac namespac http ari apach org xmln transact v2 namespac namespac namespac configur two assum list initi support namespac config http ari apach org xmln jpa v1 http ari apach org xmln jpa v2 http ari apach org xmln transact v1 http ari apach org xmln transact v2 namespac caus gener xml element namespac gener respect enabl element',
#   0],
#  [' ari subsystem implement bundl must provid offici capabl compendium v6 state 134 19 capabl capabl osgi implement namespac declar implement specif osgi subsystem capabl must also declar use constraint org osgi servic subsystem packag exampl code provid capabl osgi implement osgi implement osgi subsystem version version use org osgi servic subsystem code capabl must follow rule defin osgi implement namespac page 997 capabl osgi servic namespac repres subsystem servic capabl must also declar use constraint org osgi servic subsystem packag exampl code provid capabl osgi servic objectclass list string org osgi servic subsystem subsystem use org osgi servic subsystem code',
#   0],
#  [' add declar transact support apach ari aim alllow declar transact use via blueprint la jee declar transact support exampl blueprint xmln http www osgi org xmln blueprint v1 xmln xsi http www w3 org 2001 xmlschema instanc xsi schemaloc http www osgi org xmln blueprint v1 xmln tx http ari apach org xmln transact v1 default activ lazi bean id persistenceimpl class org apach ari sampl blog persist blogpersistenceserviceimpl tx transact method valu requir bean blueprint',
#   0],
#  [' support m2e increment build blueprint maven plugin', 0],
#  [' cm manag compon destroy method call singl integ argument destroy method cm manag compon consid compat method contain singl integ argument requir use placehold integ argument requir lead confus use blueprint cm code titl cmmanagedservicefactori java borderstyl solid privat method finddestroymethod class clazz method method null componentdestroymethod null componentdestroymethod length list method method reflectionutil findcompatiblemethod clazz componentdestroymethod new class int class method null method isempti method method get return method code',
#   0],
#  [' wsdl2java also gener dual channel client code current wsdl2java gener client stub sync osync call singl connect commun sinc axis2 support also dual channel commun tool also gener java code blockingdualcli stub nonblockingdualcli stub',
#   0],
#  [' wsdl return ip address instead hostnam may relat axis2 700 fix ip address return instead hostnam url wsdl file deo make url less robust machin dyanmic ip address',
#   0],
#  [' replac servic endpoint serv origin wsdl use useoriginalwsdl param use recent ad useoriginalwsdl attribut servic xml serv wsdl meta inf thank fix would nice replac endpoint address use request url context serv origin wsdl',
#   0],
#  [' improp error messag display click upload button without select archiv follow error messag display user click upload button without select archiv follow error occur unsupport file type error messag chang archiv select upload step reproduc log axis2 administr consol click upload servic left navig pane click upload button without specifi archiv actual result follow error occur unsupport file type error messag display expect result error messag chang follow error occur archiv select upload',
#   0],
#  [' java2wsdl gener unknown namespac issu come user mail list http marc theaimsgroup com 115937715900004 java2wsdl gener unknown namespac http test xsd use current nightli servic class method sayhello return array simpl java bean hellobean run java2wsdl sayhello sayhellorespons namespac http aaa bbb type hellobean unknown namespac http test xsd bug axis2 std snapshot bin bin java2wsdl bat cn test testservice1 cp tn http aaa bbb tp xxx stn http aaa bbb type stp yyy sn testservice1 testservice1 wsdl gener wsdl like wsdl definit xmln soap12 http schema xmlsoap org wsdl soap12 xmln http http schema xmlsoap org wsdl http xmln mime http schema xmlsoap org wsdl mime xmln ns1 http aaa bbb type xmln xxx http aaa bbb xmln soap http schema xmlsoap org wsdl soap xmln wsdl http schema xmlsoap org wsdl targetnamespac http aaa bbb wsdl type xs schema xmln xs http www w3 org 2001 xmlschema xmln ax22 http test xsd targetnamespac http test xsd attributeformdefault qualifi elementformdefault qualifi xs element name hellobean type ax22 hellobean xs complextyp name hellobean xs sequenc xs element name ret1 type xs string xs element name ret2 type xs int xs element name ret3 type xs long xs element name ret4 type xs doubl xs element name ret5 type xs float xs element name ret6 type xs short xs element name ret7 type xs boolean xs sequenc xs complextyp xs schema xs schema xmln xs http www w3 org 2001 xmlschema xmln gen798 http test xsd xmln ax21 http aaa bbb type targetnamespac http aaa bbb type attributeformdefault qualifi elementformdefault qualifi xs element name sayhello xs complextyp xs sequenc xs element name var1 type xs string xs element name var2 type xs int xs element name var3 type xs long xs element name var4 type xs doubl xs element name var5 type xs float xs element name var6 type xs short xs element name var7 type xs boolean xs sequenc xs complextyp xs element xs element name sayhellorespons xs complextyp xs sequenc xs element name return maxoccur unbound type gen798 hellobean nillabl true xs sequenc xs complextyp xs element xs schema wsdl type',
#   0],
#  [' provid mechan obtain effect polici messag context need mechan obtain effect polici given messag messag context return org apach neethi polici instanc',
#   0],
#  [' endpointrefer serial deseri consolid endpointrefer class issu depend issu http issu apach org jira brows axis2 993 current endpoint refer serial deseri code exist four differ place endpointrefer addressingfinalinhandl addressingsubmissioninhandl addressingouthandl code consolid one place endpointrefer would greatli simplifi address handler patch follow',
#   0],
#  [' properti ws_addressing_vers current overload properti ws_addressing_vers current use indic address handler run base address namesapc defin properti address handler run base properti null would like chang semant properti indic address handler run base address namespac allow anoth handler secur handler abl specifi address handler run inbound messag handler tri today use properti neither address handler would run due overload semant patch follow',
#   0],
#  [' basic authent support work provid http basic authent support per jaxw specif section 10 secur',
#   0],
#  [' build maven tracker bug serv follow purpos keep peopl inform ongo effort prevent someon els start work topic possibl attract peopl start work collect depend relat bug like axis2 1128',
#   0],
# ...
#   0],
#  [' comment impala shell interact mode handl properli caus syntax error wrong result although impala shell allow singl line comment batch mode via option give unrecogn command error comment enter command prompt localhost 21000 foo unrecogn command localhost 21000 foo unrecogn command command shell allow comment way process sometim user run code might copi past rang line sometim user conduct interactiv experi might enter commentari impala shell session use script save session output log file includ comment request impala 191 ask impala shell allow style comment also',
#   0],
#  [' support comment common command shell oracl mysql databas support singl line multi line comment notat impala shell blah sql current give unrecogn command comment silent ignor exampl basic mysql sampl code http download mysql com doc world sql zip immedi give bunch unrecogn command error due mix comment top file regardless whether actual sql command syntax compat base pattern error messag seem like impala realli ignor whatev delimit might case spuriou messag actual encount',
#   0],
#  [' order give syntax error certain case queri work select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order vcf_po limit 100 queri fail syntax error select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order limit 100 error com cloudera impala common analysisexcept analysi except select vcf_flat_text vcf_flat_text inner join select distinct chrom po cosmic cosmic_distinct vcf_flat_text vcf_chrom cosmic_distinct chrom vcf_flat_text vcf_po cosmic_distinct po order limit 100 com cloudera impala analysi analysiscontext analyz analysiscontext java 195 com cloudera impala servic frontend createexecrequest frontend java 387 com cloudera impala servic jnifrontend createexecrequest jnifrontend java 119 caus com cloudera impala common analysisexcept order ordin refer select list com cloudera impala analysi selectstmt substituteordin selectstmt java 493 com cloudera impala analysi querystmt createsortinfo querystmt java 87 com cloudera impala analysi selectstmt analyz selectstmt java 154 com cloudera impala analysi analysiscontext analyz analysiscontext java 192 clear first column work',
#   0],
#  [' throw error default order limit reach default queri option set limit default_order_by_limit alreadi exist describ http ccp cloudera com display impala10betadoc languag refer howev case default limit set reach user need notifi limit reach',
#   0],
#  [' runtim state contain queri string runtim state someth like contain queri string extrem use debug core dump anoth way get run queri alreadi',
#   0],
#  [' issu s3 error messag recommend secret key url access id secret key embed impala config file like recommend attempt creat tabl s3 produc error messag mention emb set url specifi locat attribut localhost 21000 creat tabl sample_data_s3 like sample_data store parquet locat s3a impala demo sample_data error analysisexcept null caus illegalargumentexcept aw access key id secret access key must specifi usernam password respect s3a url set fs s3a awsaccesskeyid fs s3a awssecretaccesskey properti respect want peopl suppli set via config properti catch error issu differ messag mention properti name url method',
#   0],
#  [' clarifi creat tabl error messag long char varchar column current defin column length 32672 give error like localhost 21000 creat tabl varchar_million varchar 1000000 error analysisexcept varchar size must 32672 size set 1000000 localhost 21000 creat tabl char_million char 1000000 queri creat tabl char_million char 1000000 error analysisexcept char size must 32672 size set 1000000 size set busi make look like impala adjust size allow valu continu creat tabl statement realli bail base rang valu localhost 21000 show tabl like million queri show tabl like million fetch row 04 suggest reword error messag along line type size ld rang must 32672 also low number produc cryptic sort error localhost 21000 creat tabl char_million char queri creat tabl char_million char error analysisexcept syntax error line creat tabl char_million char encount expect integ liter seem confus peopl might think integ liter rather negat oper appli liter length zero give error messag localhost 21000 creat tabl char_million char queri creat tabl char_million char error analysisexcept char size must size set perhap case could use messag say valu must 32672 avoid user go trial error low high valu',
#   0],
#  [' issu distinct error messag unsupport subqueri syntax localhost 21000 select higher count million_numb select cast appx_median doubl million_numb union select lower count million_numb select cast appx_median doubl million_numb error analysisexcept unsupport statement contain subqueri select higher count appx_median million_numb select cast appx_median doubl appx_median million_numb union select lower count appx_median million_numb select cast appx_median doubl appx_median million_numb believ unsupport aspect union differ queri contain subqueri gener unsupport messag follow origin lengthi queri make hard figur fail differ case error could occur suggest make uniqu messag exampl error subqueri cannot use claus union queri low prioriti expect go',
#   0],
#  [' show time info shell command like see time info impala shell command compar perform queri etl oper howev use execut command like hdf df put giant_fil indic long took want see time command like use set shell seem like logic place show elaps time understand difficult implement due command go real impalad connect',
#   0],
#  [' throw away summari next success statement mind much non queri statement like use describ caus summari output previou queri discard look like even syntax error make summari unavail suggest keep summari around next statement least pass analysi check localhost 21000 select count billion_numb count 1000000000 localhost 21000 summar error analysisexcept syntax error line summar encount identifi expect alter comput creat describ drop explain insert invalid load refresh select show use valu caus except syntax error localhost 21000 summari error queri id found could retriev summari queri',
#   0],
#  [' quot argument pass use impala shell databas name parquet back parquet keyword great find name conflict use option parquet impala shell fail databas name get quot pass along use statement impala shell localhost parquet start impala shell without kerbero authent connect localhost 21000 server version impalad version cdh4 intern releas build b960fdb4fdf4d59bbe10855e92a8f36c778262e6 welcom impala shell press tab twice see list avail command copyright 2012 cloudera inc right reserv shell build version impala shell v1 cdh4 intern b960fdb built fri jun 20 19 51 13 pdt 2014 queri use parquet error analysisexcept syntax error line use parquet encount parquet expect identifi caus except syntax error quot done automat',
#   0],
#  [' reduc repetit parquet decim messag cdh see cdh localhost 21000 creat tabl t4 tinyint smallint int bigint boolean timestamp string float doubl decim decim decim 38 decim 38 15 store parquet error decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon decim column support everi compon cdh4 particularli hive impala read write column hive cannot mean data written tabl might readabl compon tabl t4 actual creat think messag warn error sinc messag actual state name applic decim column repeat decim column add extra inform way limit messag one occurr per creat alter tabl',
#   0],
#  [' receiv report unknown queri id log info error messag see get report unknown queri id often benign sinc queri usual realli close cancel action bump vlog',
#   0],
#  [' add queri text query_profil page ad sql text query_profil page make commun debug info easier',
#   0],
#  [' upgrad apach common fileupload later', 0],
#  [' selectivefoldingfilt jena text current support accent fold jena text lucen provid asciifoldingfilt filter enabl search deja vu match liter d? vu data use nation librari finland finto fi skosmo fold much finnish alphabet addit latin ascii use letter ? fold ascii need lucen analyz configur exclud list someth like new selectivefoldingfilt string excludechar also configur via jena assembl like analyz support jena text also briefli discuss skosmo user mail list http group googl com msg skosmo user x3zr_urbqt0 q90 o_idaqaj appar norwegian problem discuss kinow initi code implement featur think turn pr fairli soon',
#   0],
#  [' add systemd unit file fuseki discuss user mail list could add systemd unit file fuseki make easier set systemd base linux instal make pr soon ping jneubert origin request',
#   0],
#  [' make top pom parent make pom top code tree parent pom modul merg jena project pom remov modul jena project',
#   0],
#  [' add dynamicdataset sdb support name queri sdb current support name queri ad dynamicdataset support resolv',
#   0],
#  [' improv graphutil oper consid rel graph size bulk graphutil oper addinto deletefrom could improv loop smaller graph differ algorithm depend whether sourc destin graph smaller',
#   0],
#  [' querybuild addfilt accept anyth string addfilt take claus construct creat filter string',
#   0],
#  [' command line tool run embed fuseki server run embed server use headless fuseki server without fuseki standard ui without admin function togeth static html page cover run fuseki2 sparql org',
#   0],
#  [' httpop switch use pool httpclient default default cach content complic big impact unsuspect client code cach lot larg item use ram',
#   0],
#  [' riot mainten post jena 1306 scope lot clear simplifi parser creation particular two set creat parser set profil chang set profil thing need make code control error handl control prefix part reader parser engin constructor pr 234 start roll earlier improv elepha made sens mainten bit bit look like becom work',
#   0],
#  [' bad runtim regex pattern print stacktrac runtim regex pattern mani mani log messag http list apach org thread html 0d6042871739323716346ebfff76e64ede7c39a52eacbc0ab17d6d3c 3cdev jena apach org 3e',
#   0],
#  [' except rewrap httpqueri mask error respons server sparql server respond request error 500 error tomcat error respons bodi provid detail inform went wrong respons inform includ underyl httpexcept mask faulti error handl code org apach jena sparql engin http httpqueri rewrap method specifi httpex root caus except httpex getcaus ensur respons bodi inform preserv',
#   0],
#  [' drop solr support jena text jena spatial discuss dev list propos drop solr support jena text jena spatial reason evid run document unit test specif solr whether work cannot easili verifi time gain featur ad jena text recent year multilingu index store liter valu variou special analyz upgrad lucen jena 1250 would probabl break sinc solr use depend lucen though due reason tell elasticsearch support jena text develop anuj kumar offer kind extern text index function solr support use offer fun look effect maintain code know anyon use whether even work heard user jena text solr long time recent exchang http comment gmane org gmane comp apach jena user 3369 could find user list 2013 end unclear whether user ever got work okay anoth thread http thread gmane org gmane comp apach jena user 8892 april may 2016 solr appar use discuss issu volunt actual clean get agreement',
#   0],
#  [' separ modul elasticsearch elasticsearch quit larg separ modul mean inclus non inclus fuseki control easili pr 245',
#   0],
#  [' spatial queri slow larg databas load geonam jena spatial queri take 3s execut queri prefix spatial http jena apach org spatial prefix rdf http www w3 org 2000 01 rdf schema select distinct place place spatial intersectbox 32 55668 117 12865 32 56668 117 13865 data download http drive googl com file 0b fwypjyt1goyvvizf9rouxzclk view usp share small dataset queri execut 200m fast notic access lucen index directli queri also fast 20m issu may relat po process lucen result',
#   0],
#  [' execut cmd line queri insid transact command line arq queri put read transact around queri execut dataset support transact dataset may requir transact use',
#   0],
#  [' rdfconnect rdfconnect api bring togeth part sparql queri updat graph store protocol',
#   0],
#  [' make resultset closeabl current queryexecut close done work resultset mean write function return resultset expect queryexecut properli close problem fix like make resultset interfac extend closableiter probabl autoclos fall back ad close case plan caus someth aw happen put refer queryexecut probabl refer autoclos streamresultset streamresultset close implement deleg otherwis noth resultsetstream close get end make sure close relev queryexecut element idempot crash doubl close otherwis behavior follow later qe close could caus troubl make close op resultsetmem point punish user use use resultsetmem autoclos put javadoc resultsetrewind self close resultset rewind close hit end think exactli resultsetpeek rewind get blindsid corner condit isclos method resultset would call attent fuzzi involv volunt',
#   0],
#  [' revis graph capabl graph capabl origin featur jena reflect variat implement capabl make sens nowaday unclear jira mainten see also discuss dev http list apach org thread html 9d5a82d701b84ec5397e4441a593283ebf7af4bf8619c495d2d43d01 3cdev jena apach org 3e dec 2016',
#   0],
#  [' make rdf primit serializ alway use jena handl rdf data apach spark howev want store result rdd data ex rdd tripl binari format call rdd saveasobjectfil method rdd saveasobjectfil requir java io serializ interfac see follow code http github com apach spark blob v1 core src main scala org apach spark rdd rdd scala l1469 http github com apach spark blob v1 core src main scala org apach spark util util scala l79 l86 see rdd saveasobjectfil call util serial method util serial method requir rdd wrap object implement java io serializ interfac exampl want save rdd tripl object tripl must implement java io serializ implement java io serializ think improv usabl apach spark',
#   0],
#  [' enhanc sdbload cover quad format trigger bulk loader print progress', 0],
#  [' support mariadb jdbc driver mariadb jdbc compat mysql jdbc driver differ licens mariadb jdbc driver lgpl mysql jdbc driver gpl special foss except addit mariadb jdbc driver respons jdbc mysql url support driver two part mariadb explicitli chosen sdb sdbtype registr mariadb map org mariadb jdbc driver ideal build right jdbc url case url explicitli provid part setup mysql mariadb jdbc driver classpath treat special case load jdbc driver look mysql classnam com mysql jdbc driver fail code also look org mariadb jdbc driver point jena sourc binari ship either jdbc driver',
#   0],
#  [' improv tokenizertext warn error handl put place structur warn token error enabl need test see knock effect ideal combin parser level error recoveri see also email discuss user nov 2016 http list apach org thread html 0f16e1e124abde11dbf40a65e9858a9fadd5fb4d67bffc76fd528a1a 3cuser jena apach org 3e',
#   0],
#  [' improv assembl error report target assembl exist', 0],
#  [' limit number outstand write transact tdb tdb journal grow due write back block long run reader success overlap short read mani updat user email http list apach org thread html 99b01f1dc7af86e0832279a85da6963985fc9f1f2c36d3c3969aaeb1 3cuser jena apach org 3e may caus effect accumul layer wrapper consum heap 300 time lock new transact wait flush journal mani layer',
#   0],
#  ...]

# %% [markdown]
# feature_words.py

# %%
import pickle
from nltk import word_tokenize, pos_tag
from nltk.stem import WordNetLemmatizer
import re
from collections import Counter
import string
import numpy as np
import math

def clean_text(text):
    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text)
    text.lower();
    # Get the difference of all ASCII characters from the set of printable characters
    nonprintable = set([chr(i) for i in range(128)]).difference(string.printable)
    # Use translate to remove all non-printable characters
    return text.translate({ord(character): None for character in nonprintable})

def tokenization(text):
    return word_tokenize(text)

def pos_tagging(text):

    return pos_tag(text)

def lemmatization(pos_tags):
    adjective_tags = ['JJ', 'JJR', 'JJS']
    wordnet_lemmatizer = WordNetLemmatizer()
    lemmatized_text = []
    for word in pos_tags:
        if word[1] in adjective_tags:
            lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0], pos="a")))
        else:
            lemmatized_text.append(str(wordnet_lemmatizer.lemmatize(word[0])))  # default POS = noun
    return lemmatized_text

def stop_word_removal(pos_tags_lem, lem_text):
    stopwords = []

    wanted_POS = ['NN', 'NNS', 'NNP', 'NNPS', 'JJ', 'JJR', 'JJS', 'VBG', 'FW']

    for word in pos_tags_lem:
        if word[1] not in wanted_POS:
            stopwords.append(word[0])

    punctuations = list(str(string.punctuation))

    stopwords = stopwords + punctuations
    # BUG-1 : There was no file with name long_stopwords.txt so the file download from the Source = https://www.ranks.nl/stopwords.
    stopword_file = open(MASTER_PATH + "/src/dataset/long_stopwords.txt", "r")
    # Source = https://www.ranks.nl/stopwords

    lots_of_stopwords = []

    for line in stopword_file.readlines():
        lots_of_stopwords.append(str(line.strip()))

    stopwords_plus = []
    stopwords_plus = stopwords + lots_of_stopwords
    stopwords_plus = set(stopwords_plus)

    processed_text = []
    for word in lem_text:
        if word not in stopwords_plus:
            processed_text.append(word)

    return processed_text, stopwords_plus

if __name__ == '__main__':
    load = open(MASTER_PATH + "/src/dataset/binary_class_dataset.pickle", "rb")
    tasks = pickle.load(load)
    load.close()
    print(tasks[0])
    print("tasks loaded.....")

    preprocessed_tasks = []

    all_words = []
    freq_words_without_freq = []

    for index in range(len(tasks)):

        # without preprocessing
        old_task = tasks[index]
        text = tasks[index][0].lower()
        cleaned_text = clean_text(text)
        words = re.findall(r'\w+', cleaned_text)
        # without preprocessing
        for item in words:

            all_words.append(item)


    counts = Counter(all_words).most_common(5000)

    for index in range(len(counts)):
        freq_words_without_freq.append(counts[index][0])


    file = open(MASTER_PATH + "/src/dataset/freq_words_without_preprocessing.pickle", "wb")
    pickle.dump(freq_words_without_freq, file)
    file.close()
    print("all_phrases_without_freq saved......")
# Out:
# [' anoth blueprint sampl contribut day test blueprint mbean gener complex blueprint sampl sampl user learn defin nest compon blueprint xml run sampl besid osgi framework bundl requir coreopt mavenbundl groupid org apach felix artifactid org apach felix configadmin versionasinproject coreopt mavenbundl groupid org apach felix artifactid org apach felix eventadmin versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log api versionasinproject coreopt mavenbundl groupid org ops4j pax log artifactid pax log servic versionasinproject coreopt mavenbundl groupid org apach ari blueprint artifactid org apach ari blueprint versionasinproject coreopt mavenbundl groupid org apach ari artifactid org apach ari util coreopt mavenbundl groupid org apach ari jmx artifactid ari jmx blueprint versionasinproject', 0]
# tasks loaded.....
# all_phrases_without_freq saved......

# %% [markdown]
# 3. featuresets_generation.py

# %%
import pickle
import random

def load_dataset():
    file = open(MASTER_PATH + "/src/dataset/shuffle_dataset.pickle", "rb")
    dataset = pickle.load(file)
    file.close()
    print("dataset of length " , len(dataset) , " is loaded.....")
    return dataset

def load_features():
    # file = open("./dataset/features.pickle", "rb")
    file = open(MASTER_PATH + "/src/dataset/features_without_pp.pickle", "rb")
    features = pickle.load(file)
    file.close()
    print("features of length " , len(features) , " is loaded.....")
    # print(features[:100])
    return features

def find_features(w_features, t_words):
    words = t_words
    features = {}
    for f in w_features:
        features[f] = 0

    for f in features:
        if f in words:
            features[f] += 1
    return features


def make_featuresets(word_features):

    documents_f = open(MASTER_PATH + "/src/T&T/testing.pickle", "rb")
    testing_files = pickle.load(documents_f)
    documents_f.close()
    print(str(len(testing_files)) + " testing files loaded.....")

    testing_featureset = []

    for index in range(len(testing_files)):
        testing_featureset.append(
            [find_features(word_features, testing_files[index][2]),
             testing_files[index][1]])
    # one bug was here fixed, 
    save_featuresets = open(MASTER_PATH + "/src/feature_modeling/testing_featureset.pickle", "wb")
    pickle.dump(testing_featureset, save_featuresets)
    save_featuresets.close()
    print("testing featuresets saved.....")
    print("===============>")

    for t_index in range(10):
        documents_f = open(MASTER_PATH + "/src/T&T/training" + str(t_index + 1) +".pickle", "rb")
        training_files = pickle.load(documents_f)
        documents_f.close()
        print(str(len(training_files)) + " training files loaded.....")

        training_featureset = []

        for index in range(len(training_files)):
            training_featureset.append(
                [find_features(word_features, training_files[index][2]),
                 training_files[index][1]])
        # one bug was here the path for saving feature_modeling.pickle file was /src 
        # so I change this path with /src/feature_modeling/ which we will use next part.
        save_featuresets = open(MASTER_PATH + "/src/feature_modeling/feature_modeling" + str(t_index + 1) + ".pickle","wb")
        pickle.dump(training_featureset, save_featuresets)
        save_featuresets.close()
        print("training featuresets " + str(t_index + 1) + " saved.....")
        print("===============>")


if __name__ == '__main__':
    # dataset = load_dataset()
    features = load_features()
    # saperate_training_and_testing_data(dataset)
    make_featuresets(features)
# Out:
# features of length  5000  is loaded.....
# 1336 testing files loaded.....
# testing featuresets saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 1 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 2 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 3 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 4 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 5 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 6 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 7 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 8 saved.....
# ===============>
# 1200 training files loaded.....
# training featuresets 9 saved.....
# ===============>
# 1228 training files loaded.....
# training featuresets 10 saved.....
# ===============>

# %% [markdown]
# 4. refactoring_prediction.py (ATTENTION)

# %%
import nltk
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# classifiers = ['SVM', 'NB', 'MNB', 'BNB', 'LR', 'RF']
classifiers = ['SVM']
# data loading
featuresets_f = open(MASTER_PATH + "/src/feature_modeling/testing_featureset.pickle", "rb")
testing_set = pickle.load(featuresets_f)
featuresets_f.close()
print("lenght of testing dataset: ", len(testing_set))

for t_index in range(10):

    print("iteration " + str(t_index + 1))
    featuresets_f = open(MASTER_PATH + "/src/feature_modeling/feature_modeling" + str(t_index + 1) + ".pickle", "rb")
    training = pickle.load(featuresets_f)
    featuresets_f.close()
    print("lenght of training dataset: ", len(training))

    for cls in classifiers:
        if cls == 'SVM':
            classifier = SklearnClassifier(LinearSVC())
            classifier.train(training)
        elif cls == 'NB':
            classifier = nltk.NaiveBayesClassifier.train(training)
            classifier.train(training)
        elif cls == 'MNB':
            classifier = SklearnClassifier(MultinomialNB())
            classifier.train(training)
        elif cls == 'BNB':
            classifier = SklearnClassifier(BernoulliNB())
            classifier.train(training)
        elif cls == 'LR':
            classifier = SklearnClassifier(LogisticRegression())
            classifier.train(training)
        elif cls == 'RF':
            classifier = SklearnClassifier(RandomForestClassifier())
            classifier.train(training)
        # prediction
        y_true, y_pred = [], []

        for i, (feats, label_true) in enumerate(testing_set):
            label_pred = classifier.classify(feats)
            y_true.append(label_true)
            y_pred.append(label_pred)

        # save_classifier = open("./trained_classifiers/LRall.pickle", "wb")
        save_classifier = open(MASTER_PATH + "/src/trained_classifiers/" + cls + str(t_index + 1) + ".pickle", "wb")
        pickle.dump(classifier, save_classifier)
        save_classifier.close()

        # save_classifier = open("./y_true_pred/y_true_LRall.pickle", "wb")
        save_classifier = open(MASTER_PATH + "/src/y_true_pred/y_true_" + cls + str(t_index + 1) +  ".pickle", "wb")
        pickle.dump(y_true, save_classifier)
        save_classifier.close()

        # save_classifier = open("./y_true_pred/y_pred_LRall.pickle", "wb")
        save_classifier = open(MASTER_PATH + "/src/y_true_pred/y_pred_" + cls + str(t_index + 1) +  ".pickle", "wb")
        pickle.dump(y_pred, save_classifier)
        save_classifier.close()

        print(cls + " for iteration " + str(t_index + 1) + " done.....")
        print("=========>>")
# Out:
# lenght of testing dataset:  1336
# iteration 1
# lenght of training dataset:  1200
# SVM for iteration 1 done.....
# =========>>
# iteration 2
# lenght of training dataset:  1200
# SVM for iteration 2 done.....
# =========>>
# iteration 3
# lenght of training dataset:  1200
# SVM for iteration 3 done.....
# =========>>
# iteration 4
# lenght of training dataset:  1200
# SVM for iteration 4 done.....
# =========>>
# iteration 5
# lenght of training dataset:  1200
# SVM for iteration 5 done.....
# =========>>
# iteration 6
# lenght of training dataset:  1200
# SVM for iteration 6 done.....
# =========>>
# iteration 7
# lenght of training dataset:  1200
# SVM for iteration 7 done.....
# =========>>
# iteration 8
# lenght of training dataset:  1200
# SVM for iteration 8 done.....
# =========>>
# iteration 9
# lenght of training dataset:  1200
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# SVM for iteration 9 done.....
# =========>>
# iteration 10
# lenght of training dataset:  1228
# SVM for iteration 10 done.....
# =========>>

# %% [markdown]
# 5. multi-label_classifiers.py

# %%
# !pip install pyodbc
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyodbc
#   Downloading pyodbc-4.0.35-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (333 kB)
#      |████████████████████████████████| 333 kB 5.1 MB/s
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.35

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import hamming_loss, accuracy_score, precision_score, recall_score, f1_score, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pyodbc
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re


df_text = pd.read_csv(MASTER_PATH + '/src/dataset/TextPreprocessed.csv', encoding='iso-8859-1')
# print(df_text.head())
df_tags = pd.read_csv(MASTER_PATH + '/src/dataset/Tag.csv', encoding='iso-8859-1')

num_classes = 14
grouped_tags = df_tags.groupby("Tag").size().reset_index(name='count')
most_common_tags = grouped_tags.nlargest(num_classes, columns="count")
df_tags.Tag = df_tags.Tag.apply(lambda tag : tag if tag in most_common_tags.Tag.values else None)
df_tags = df_tags.dropna()

counts = df_tags.Tag.value_counts()
firstlast = counts[:5].append(counts[-5:])
firstlast.reset_index(name="count")

# print(firstlast)

def tags_for_question(question_id):
    return df_tags[df_tags['Id'] == question_id].Tag.values

def add_tags_column(row):
    row['Tags'] = tags_for_question(row['Id'])
    return row

df_questions = df_text.apply(add_tags_column, axis=1)

multilabel_binarizer = MultiLabelBinarizer()
multilabel_binarizer.fit(df_questions.Tags)
Y = multilabel_binarizer.transform(df_questions.Tags)

count_vect = CountVectorizer()
X_counts = count_vect.fit_transform(df_questions.Text.values.astype('U'))

tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X_counts)

ros = RandomOverSampler(random_state=9000)

X_tfidf_resampled, Y_tfidf_resampled = ros.fit_resample(X_tfidf, Y)

x_train_tfidf, x_test_tfidf, y_train_tfidf, y_test_tfidf = train_test_split(X_tfidf_resampled, Y_tfidf_resampled, test_size=0.2, random_state=9000)


def hamming_score(y_true, y_pred, normalize=True, sample_weight=None):
    print(y_true.shape[0])
    print(y_pred)

    acc_list = []
    for i in range(y_true.shape[0]):
        set_true = set(np.where(y_true[i])[0])
        set_pred = set(np.where(y_pred[i])[0])
        tmp_a = None
        if len(set_true) == 0 and len(set_pred) == 0:
            tmp_a = 1
        else:
            # tmp_a = len(set_true.union(set_pred))
            tmp_a = len(set_true.intersection(set_pred))/float(len(set_true.union(set_pred)) )
        acc_list.append(tmp_a)
    # print(acc_list)
    return np.mean(acc_list)

def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    # print("Hamming loss: {}".format(hamming_loss(y_test_tfidf, y_pred)))
    print("Hamming score: {}".format(hamming_score(y_test_tfidf, y_pred)))
    # print('Subset accuracy: {0}'.format(accuracy_score(y_test_tfidf, y_pred, normalize=True, sample_weight=None)))
    # print('Subset precision: {0}'.format(precision_score(y_test_tfidf, y_pred, average='samples')))
    print("---")

# sgd = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42, max_iter=6, tol=None)
#lr = LogisticRegression()
#mn = MultinomialNB()
svm = LinearSVC()

for classifier in [svm]:
    clf = OneVsRestClassifier(classifier)
    clf.fit(x_train_tfidf, y_train_tfidf)
    y_pred = clf.predict(x_test_tfidf)
    # print_score(y_pred, classifier)
    print(classification_report(y_test_tfidf, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       535
#            1       0.57      0.07      0.13       525
#            2       0.90      0.92      0.91       531
#            3       0.90      0.66      0.76       539
#            4       0.89      0.87      0.88       511
#            5       0.83      0.65      0.73       519
#            6       0.90      0.71      0.79       544
#            7       0.84      0.45      0.58       499
#            8       0.90      0.92      0.91       494
#            9       0.92      0.77      0.84       512
#           10       0.93      0.82      0.87       519
#           11       0.94      0.82      0.88       507
#           12       0.90      0.65      0.75       547
#           13       0.71      0.21      0.33       518
#
#    micro avg       0.89      0.68      0.77      7300
#    macro avg       0.86      0.68      0.73      7300
# weighted avg       0.86      0.68      0.73      7300
#  samples avg       0.68      0.68      0.68      7300
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
